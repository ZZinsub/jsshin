# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/corazzon/finance-data-analysis/blob/main/4.1%20ETF%20%EB%AA%A9%EB%A1%9D%20%EC%88%98%EC%A7%91-input.ipynb)
#
#
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리 불러오기
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests
import pandas as pd
import numpy as np
import requests
import html5lib

# %%
# 수집할 url을 가져오기
url = 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'

# %% [markdown]
# ## Pandas를 통한 요청

# %%
pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22212\1087222485.py in <module>
# ----> 1 pd.read_html(url)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111     io = stringify_path(io)
#    1112
# -> 1113     return _parse(
#    1114         flavor=flavor,
#    1115         io=io,
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     913     retained = None
#     914     for flav in flavor:
# --> 915         parser = _parser_dispatch(flav)
#     916         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     917
#
# ~\anaconda3\lib\site-packages\pandas\io\html.py in _parser_dispatch(flavor)
#     862     if flavor in ("bs4", "html5lib"):
#     863         if not _HAS_HTML5LIB:
# --> 864             raise ImportError("html5lib not found, please install it")
#     865         if not _HAS_BS4:
#     866             raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아오기
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '459580',
#     'etfTabCode': 6,
#     'itemname': 'KODEX CD금리액티브(합성)',
#     'nowVal': 1035155,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.01,
#     'nav': 1035156.0,
#     'threeMonthEarnRate': 0.884,
#     'quant': 344339,
#     'amonut': 356445,
#     'marketSum': 83168},
#    {'itemcode': '357870',
#     'etfTabCode': 6,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 54265,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 54258.0,
#     'threeMonthEarnRate': 0.8456,
#     'quant': 132995,
#     'amonut': 7216,
#     'marketSum': 73403},
#    {'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 37460,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.35,
#     'nav': 37556.0,
#     'threeMonthEarnRate': 6.584,
#     'quant': 1895070,
#     'amonut': 70864,
#     'marketSum': 63813},
#    {'itemcode': '423160',
#     'etfTabCode': 6,
#     'itemname': 'KODEX KOFR금리액티브(합성)',
#     'nowVal': 106685,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 106678.0,
#     'threeMonthEarnRate': 0.8841,
#     'quant': 609048,
#     'amonut': 64976,
#     'marketSum': 52336},
#    {'itemcode': '449170',
#     'etfTabCode': 6,
#     'itemname': 'TIGER KOFR금리액티브(합성)',
#     'nowVal': 105225,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 105221.0,
#     'threeMonthEarnRate': 0.8869,
#     'quant': 42740,
#     'amonut': 4497,
#     'marketSum': 37320},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 17625,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.48,
#     'nav': 17593.0,
#     'threeMonthEarnRate': 7.2586,
#     'quant': 1144322,
#     'amonut': 20162,
#     'marketSum': 32474},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 109905,
#     'risefall': '2',
#     'changeVal': 485,
#     'changeRate': 0.44,
#     'nav': 109731.0,
#     'threeMonthEarnRate': 5.4041,
#     'quant': 114739,
#     'amonut': 12607,
#     'marketSum': 31455},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 109885,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.05,
#     'nav': 109920.0,
#     'threeMonthEarnRate': 0.6592,
#     'quant': 7426,
#     'amonut': 815,
#     'marketSum': 28325},
#    {'itemcode': '465680',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 24-12 은행채(AA+이상)액티브',
#     'nowVal': 10280,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 10280.0,
#     'threeMonthEarnRate': 0.8832,
#     'quant': 49967,
#     'amonut': 513,
#     'marketSum': 26173},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 17315,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 17250.0,
#     'threeMonthEarnRate': 13.3254,
#     'quant': 1316211,
#     'amonut': 22768,
#     'marketSum': 23704},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 37525,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.35,
#     'nav': 37620.0,
#     'threeMonthEarnRate': 6.5263,
#     'quant': 827801,
#     'amonut': 31001,
#     'marketSum': 23153},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 19955,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 0.76,
#     'nav': 20174.0,
#     'threeMonthEarnRate': 10.9213,
#     'quant': 10526173,
#     'amonut': 209148,
#     'marketSum': 21561},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 13030,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.42,
#     'nav': 13060.0,
#     'threeMonthEarnRate': 6.396,
#     'quant': 191363,
#     'amonut': 2486,
#     'marketSum': 21519},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 18285,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.27,
#     'nav': 18250.0,
#     'threeMonthEarnRate': 10.3813,
#     'quant': 883642,
#     'amonut': 16153,
#     'marketSum': 21256},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 8120,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -1.46,
#     'nav': 8100.0,
#     'threeMonthEarnRate': 20.6442,
#     'quant': 1744008,
#     'amonut': 14250,
#     'marketSum': 20505},
#    {'itemcode': '455890',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 머니마켓액티브',
#     'nowVal': 52185,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 52182.0,
#     'threeMonthEarnRate': 0.9772,
#     'quant': 222371,
#     'amonut': 11604,
#     'marketSum': 15700},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 1991,
#     'risefall': '5',
#     'changeVal': -14,
#     'changeRate': -0.7,
#     'nav': 1992.0,
#     'threeMonthEarnRate': -12.0615,
#     'quant': 147938145,
#     'amonut': 295905,
#     'marketSum': 13407},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 9685,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.47,
#     'nav': 9706.0,
#     'threeMonthEarnRate': 7.0516,
#     'quant': 514085,
#     'amonut': 4969,
#     'marketSum': 12988},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 37715,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 0.37,
#     'nav': 37802.0,
#     'threeMonthEarnRate': 6.5473,
#     'quant': 162115,
#     'amonut': 6099,
#     'marketSum': 12842},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 23530,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.23,
#     'nav': 23585.0,
#     'threeMonthEarnRate': -1.8358,
#     'quant': 228754,
#     'amonut': 5352,
#     'marketSum': 12765},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 20055,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.02,
#     'nav': 20093.0,
#     'threeMonthEarnRate': -0.5701,
#     'quant': 542173,
#     'amonut': 10821,
#     'marketSum': 12735},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 23145,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.3,
#     'nav': 23143.0,
#     'threeMonthEarnRate': 10.698,
#     'quant': 14083,
#     'amonut': 325,
#     'marketSum': 12730},
#    {'itemcode': '470260',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 24-12 금융채(AA-이상)',
#     'nowVal': 51160,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 51168.0,
#     'threeMonthEarnRate': 0.8975,
#     'quant': 830,
#     'amonut': 42,
#     'marketSum': 12634},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 110435,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 110436.0,
#     'threeMonthEarnRate': 0.808,
#     'quant': 7563,
#     'amonut': 835,
#     'marketSum': 12089},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 12425,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.2,
#     'nav': 12465.0,
#     'threeMonthEarnRate': 8.3079,
#     'quant': 71926,
#     'amonut': 893,
#     'marketSum': 11940},
#    {'itemcode': '453850',
#     'etfTabCode': 6,
#     'itemname': 'ACE 미국30년국채액티브(H)',
#     'nowVal': 8265,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8276.0,
#     'threeMonthEarnRate': -4.5282,
#     'quant': 1450063,
#     'amonut': 11998,
#     'marketSum': 11571},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 16035,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.47,
#     'nav': 16064.0,
#     'threeMonthEarnRate': 6.6132,
#     'quant': 5115,
#     'amonut': 81,
#     'marketSum': 11401},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 종합채권(A-이상)액티브',
#     'nowVal': 101800,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.02,
#     'nav': 101810.0,
#     'threeMonthEarnRate': 0.4934,
#     'quant': 2146,
#     'amonut': 218,
#     'marketSum': 11296},
#    {'itemcode': '233740',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150레버리지',
#     'nowVal': 11830,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.17,
#     'nav': 11925.0,
#     'threeMonthEarnRate': 25.1059,
#     'quant': 16371002,
#     'amonut': 191048,
#     'marketSum': 10955},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 16060,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.5,
#     'nav': 16031.0,
#     'threeMonthEarnRate': 7.3203,
#     'quant': 734023,
#     'amonut': 11792,
#     'marketSum': 10632},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국S&P500',
#     'nowVal': 17830,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.51,
#     'nav': 17792.0,
#     'threeMonthEarnRate': 7.3005,
#     'quant': 173809,
#     'amonut': 3097,
#     'marketSum': 9735},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150',
#     'nowVal': 14310,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.14,
#     'nav': 14377.0,
#     'threeMonthEarnRate': 12.4577,
#     'quant': 4109473,
#     'amonut': 58396,
#     'marketSum': 9022},
#    {'itemcode': '396500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER Fn반도체TOP10',
#     'nowVal': 13210,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.88,
#     'nav': 13188.0,
#     'threeMonthEarnRate': 27.5197,
#     'quant': 1140448,
#     'amonut': 14953,
#     'marketSum': 8712},
#    {'itemcode': '458730',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국배당다우존스',
#     'nowVal': 11390,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.4,
#     'nav': 11360.0,
#     'threeMonthEarnRate': 4.8715,
#     'quant': 654279,
#     'amonut': 7452,
#     'marketSum': 8400},
#    {'itemcode': '447820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 24-10 회사채(A+이상)액티브',
#     'nowVal': 54865,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 54855.0,
#     'threeMonthEarnRate': 0.9384,
#     'quant': 26882,
#     'amonut': 1474,
#     'marketSum': 8117},
#    {'itemcode': '436140',
#     'etfTabCode': 6,
#     'itemname': 'SOL 종합채권(AA-이상)액티브',
#     'nowVal': 106380,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.07,
#     'nav': 106366.0,
#     'threeMonthEarnRate': 0.4251,
#     'quant': 3,
#     'amonut': 0,
#     'marketSum': 8115},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국나스닥100',
#     'nowVal': 18890,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.37,
#     'nav': 18859.0,
#     'threeMonthEarnRate': 5.5169,
#     'quant': 130338,
#     'amonut': 2462,
#     'marketSum': 7764},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 16420,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.46,
#     'nav': 16396.0,
#     'threeMonthEarnRate': 5.4516,
#     'quant': 252343,
#     'amonut': 4144,
#     'marketSum': 7758},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 34515,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.13,
#     'nav': 34519.0,
#     'threeMonthEarnRate': 10.1665,
#     'quant': 22174,
#     'amonut': 763,
#     'marketSum': 7655},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 106830,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 106843.0,
#     'threeMonthEarnRate': 0.7402,
#     'quant': 6481,
#     'amonut': 692,
#     'marketSum': 7536},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 41995,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 0.38,
#     'nav': 42012.0,
#     'threeMonthEarnRate': 22.1995,
#     'quant': 264676,
#     'amonut': 11055,
#     'marketSum': 7433},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 109500,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 109510.0,
#     'threeMonthEarnRate': 0.7591,
#     'quant': 8365,
#     'amonut': 916,
#     'marketSum': 7240},
#    {'itemcode': '356540',
#     'etfTabCode': 6,
#     'itemname': 'ACE 종합채권(AA-이상)KIS액티브',
#     'nowVal': 100395,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.05,
#     'nav': 100384.0,
#     'threeMonthEarnRate': 0.5354,
#     'quant': 272,
#     'amonut': 27,
#     'marketSum': 7139},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 47390,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 0.34,
#     'nav': 47507.0,
#     'threeMonthEarnRate': 6.5298,
#     'quant': 20653,
#     'amonut': 977,
#     'marketSum': 7037},
#    {'itemcode': '462010',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지소재Fn',
#     'nowVal': 7135,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.07,
#     'nav': 7145.0,
#     'threeMonthEarnRate': -4.5327,
#     'quant': 496471,
#     'amonut': 3516,
#     'marketSum': 6839},
#    {'itemcode': '453540',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 25-10 회사채(A+이상)액티브',
#     'nowVal': 52660,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 52651.0,
#     'threeMonthEarnRate': 0.9974,
#     'quant': 83773,
#     'amonut': 4411,
#     'marketSum': 6778},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 38020,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 0.29,
#     'nav': 38113.0,
#     'threeMonthEarnRate': 6.6385,
#     'quant': 43914,
#     'amonut': 1666,
#     'marketSum': 6558},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 20835,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.48,
#     'nav': 20861.0,
#     'threeMonthEarnRate': 0.9936,
#     'quant': 236979,
#     'amonut': 4925,
#     'marketSum': 6219},
#    {'itemcode': '458760',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국배당+7%프리미엄다우존스',
#     'nowVal': 10270,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.29,
#     'nav': 10243.0,
#     'threeMonthEarnRate': 3.8223,
#     'quant': 677843,
#     'amonut': 6956,
#     'marketSum': 6208},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 5850,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.68,
#     'nav': 5844.0,
#     'threeMonthEarnRate': 26.803,
#     'quant': 2169851,
#     'amonut': 12844,
#     'marketSum': 6122},
#    {'itemcode': '475630',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 1년은행양도성예금증서액티브(합성)',
#     'nowVal': 1009780,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.01,
#     'nav': 1009779.0,
#     'threeMonthEarnRate': 0.8555,
#     'quant': 20579,
#     'amonut': 20780,
#     'marketSum': 6016},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 53810,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 53798.0,
#     'threeMonthEarnRate': 0.834,
#     'quant': 7297,
#     'amonut': 392,
#     'marketSum': 5904},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 4110,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.24,
#     'nav': 4106.0,
#     'threeMonthEarnRate': -5.5046,
#     'quant': 20893689,
#     'amonut': 85987,
#     'marketSum': 5766},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 12065,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.37,
#     'nav': 12053.0,
#     'threeMonthEarnRate': 3.2646,
#     'quant': 69472,
#     'amonut': 837,
#     'marketSum': 5674},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 111460,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 111473.0,
#     'threeMonthEarnRate': 0.7412,
#     'quant': 37299,
#     'amonut': 4157,
#     'marketSum': 5352},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국빅테크10(H)',
#     'nowVal': 36840,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.04,
#     'nav': 36771.0,
#     'threeMonthEarnRate': 5.9356,
#     'quant': 80114,
#     'amonut': 2945,
#     'marketSum': 5345},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 37555,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 0.4,
#     'nav': 37663.0,
#     'threeMonthEarnRate': 6.3911,
#     'quant': 15666,
#     'amonut': 587,
#     'marketSum': 5333},
#    {'itemcode': '446720',
#     'etfTabCode': 4,
#     'itemname': 'SOL 미국배당다우존스',
#     'nowVal': 10455,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.48,
#     'nav': 10420.0,
#     'threeMonthEarnRate': 4.9102,
#     'quant': 263660,
#     'amonut': 2754,
#     'marketSum': 5228},
#    {'itemcode': '451540',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 종합채권(AA-이상)액티브',
#     'nowVal': 52530,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 52533.0,
#     'threeMonthEarnRate': 0.4878,
#     'quant': 3745,
#     'amonut': 196,
#     'marketSum': 4982},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 110930,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.06,
#     'nav': 110947.0,
#     'threeMonthEarnRate': -0.1979,
#     'quant': 8886,
#     'amonut': 985,
#     'marketSum': 4892},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'ACE 200',
#     'nowVal': 37730,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.23,
#     'nav': 37826.0,
#     'threeMonthEarnRate': 6.5344,
#     'quant': 9785,
#     'amonut': 368,
#     'marketSum': 4735},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 18280,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.44,
#     'nav': 18252.0,
#     'threeMonthEarnRate': 5.4033,
#     'quant': 114464,
#     'amonut': 2092,
#     'marketSum': 4661},
#    {'itemcode': '469830',
#     'etfTabCode': 6,
#     'itemname': 'SOL 초단기채권액티브',
#     'nowVal': 51160,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 51159.0,
#     'threeMonthEarnRate': 0.9969,
#     'quant': 136462,
#     'amonut': 6981,
#     'marketSum': 4636},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'nowVal': 70185,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.18,
#     'nav': 70140.0,
#     'threeMonthEarnRate': -1.1792,
#     'quant': 32203,
#     'amonut': 2259,
#     'marketSum': 4555},
#    {'itemcode': '365780',
#     'etfTabCode': 6,
#     'itemname': 'ACE 국고채10년',
#     'nowVal': 87165,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.02,
#     'nav': 87190.0,
#     'threeMonthEarnRate': -0.326,
#     'quant': 4765,
#     'amonut': 415,
#     'marketSum': 4375},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 리츠부동산인프라',
#     'nowVal': 4500,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.78,
#     'nav': 4511.0,
#     'threeMonthEarnRate': 4.7138,
#     'quant': 800513,
#     'amonut': 3591,
#     'marketSum': 4343},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 12740,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.2,
#     'nav': 12797.0,
#     'threeMonthEarnRate': 7.2091,
#     'quant': 1005,
#     'amonut': 12,
#     'marketSum': 4230},
#    {'itemcode': '455850',
#     'etfTabCode': 2,
#     'itemname': 'SOL AI반도체소부장',
#     'nowVal': 16490,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 0.86,
#     'nav': 16518.0,
#     'threeMonthEarnRate': 29.7207,
#     'quant': 499803,
#     'amonut': 8176,
#     'marketSum': 4106},
#    {'itemcode': '481050',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 1년은행양도성예금증서+액티브(합성)',
#     'nowVal': 1002305,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.01,
#     'nav': 1002304.0,
#     'threeMonthEarnRate': None,
#     'quant': 5264,
#     'amonut': 5276,
#     'marketSum': 3959},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 3405,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.15,
#     'nav': 3422.0,
#     'threeMonthEarnRate': -12.2266,
#     'quant': 20703658,
#     'amonut': 71040,
#     'marketSum': 3943},
#    {'itemcode': '458250',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국30년국채스트립액티브(합성 H)',
#     'nowVal': 42010,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 0.33,
#     'nav': 42147.0,
#     'threeMonthEarnRate': -7.9781,
#     'quant': 150052,
#     'amonut': 6308,
#     'marketSum': 3883},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 8120,
#     'risefall': '2',
#     'changeVal': 220,
#     'changeRate': 2.78,
#     'nav': 8130.0,
#     'threeMonthEarnRate': 7.8645,
#     'quant': 804029,
#     'amonut': 6498,
#     'marketSum': 3861},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 59485,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.03,
#     'nav': 59444.0,
#     'threeMonthEarnRate': 0.2867,
#     'quant': 2383,
#     'amonut': 141,
#     'marketSum': 3832},
#    {'itemcode': '476810',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 25-11 은행채(AA-이상)PLUS액티브',
#     'nowVal': 10075,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10080.0,
#     'threeMonthEarnRate': None,
#     'quant': 1386,
#     'amonut': 13,
#     'marketSum': 3767},
#    {'itemcode': '390390',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국반도체MV',
#     'nowVal': 20660,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.14,
#     'nav': 20602.0,
#     'threeMonthEarnRate': 17.9925,
#     'quant': 402333,
#     'amonut': 8303,
#     'marketSum': 3688},
#    {'itemcode': '379780',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P500',
#     'nowVal': 15415,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.46,
#     'nav': 15391.0,
#     'threeMonthEarnRate': 7.3602,
#     'quant': 127845,
#     'amonut': 1970,
#     'marketSum': 3684},
#    {'itemcode': '461460',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 국고채10년액티브',
#     'nowVal': 51840,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.04,
#     'nav': 51827.0,
#     'threeMonthEarnRate': -0.3174,
#     'quant': 24,
#     'amonut': 1,
#     'marketSum': 3680},
#    {'itemcode': '476450',
#     'etfTabCode': 6,
#     'itemname': '히어로즈 머니마켓액티브',
#     'nowVal': 50430,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 50427.0,
#     'threeMonthEarnRate': None,
#     'quant': 39598,
#     'amonut': 1996,
#     'marketSum': 3674},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 27890,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 0.43,
#     'nav': 27895.0,
#     'threeMonthEarnRate': 5.5652,
#     'quant': 173151,
#     'amonut': 4814,
#     'marketSum': 3668},
#    {'itemcode': '441680',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국나스닥100커버드콜(합성)',
#     'nowVal': 10365,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.39,
#     'nav': 10357.0,
#     'threeMonthEarnRate': 3.9359,
#     'quant': 287305,
#     'amonut': 2972,
#     'marketSum': 3612},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지TOP10',
#     'nowVal': 13055,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.19,
#     'nav': 13099.0,
#     'threeMonthEarnRate': 1.4797,
#     'quant': 894388,
#     'amonut': 11630,
#     'marketSum': 3525},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 37425,
#     'risefall': '2',
#     'changeVal': 130,
#     'changeRate': 0.35,
#     'nav': 37516.0,
#     'threeMonthEarnRate': 6.554,
#     'quant': 40247,
#     'amonut': 1502,
#     'marketSum': 3499},
#    {'itemcode': '455030',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 미국달러SOFR금리액티브(합성)',
#     'nowVal': 11105,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.18,
#     'nav': 11096.0,
#     'threeMonthEarnRate': 4.1823,
#     'quant': 40407,
#     'amonut': 449,
#     'marketSum': 3458},
#    {'itemcode': '446770',
#     'etfTabCode': 4,
#     'itemname': 'ACE 글로벌반도체TOP4 Plus SOLACTIVE',
#     'nowVal': 22365,
#     'risefall': '5',
#     'changeVal': -175,
#     'changeRate': -0.78,
#     'nav': 22278.0,
#     'threeMonthEarnRate': 17.2675,
#     'quant': 216591,
#     'amonut': 4839,
#     'marketSum': 3433},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 110510,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.02,
#     'nav': 110507.0,
#     'threeMonthEarnRate': 0.7936,
#     'quant': 4283,
#     'amonut': 473,
#     'marketSum': 3355},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 26685,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.09,
#     'nav': 26623.0,
#     'threeMonthEarnRate': 7.691,
#     'quant': 32320,
#     'amonut': 863,
#     'marketSum': 3336},
#    {'itemcode': '479080',
#     'etfTabCode': 6,
#     'itemname': '1Q 머니마켓액티브',
#     'nowVal': 50245,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 50242.0,
#     'threeMonthEarnRate': None,
#     'quant': 62280,
#     'amonut': 3129,
#     'marketSum': 3316},
#    {'itemcode': '394660',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'nowVal': 10920,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.32,
#     'nav': 10970.0,
#     'threeMonthEarnRate': 7.4546,
#     'quant': 41834,
#     'amonut': 457,
#     'marketSum': 3280},
#    {'itemcode': '466940',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 은행고배당플러스TOP10',
#     'nowVal': 13150,
#     'risefall': '2',
#     'changeVal': 335,
#     'changeRate': 2.61,
#     'nav': 13158.0,
#     'threeMonthEarnRate': 9.9339,
#     'quant': 311853,
#     'amonut': 4073,
#     'marketSum': 3189},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 49980,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.04,
#     'nav': 49987.0,
#     'threeMonthEarnRate': -0.09,
#     'quant': 2990,
#     'amonut': 149,
#     'marketSum': 3189},
#    {'itemcode': '467940',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 25-11 회사채(A+이상)액티브',
#     'nowVal': 10430,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10425.0,
#     'threeMonthEarnRate': 1.0664,
#     'quant': 3793,
#     'amonut': 39,
#     'marketSum': 3180},
#    {'itemcode': '304660',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 미국30년국채울트라선물(H)',
#     'nowVal': 7775,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.19,
#     'nav': 7766.0,
#     'threeMonthEarnRate': -4.3747,
#     'quant': 728582,
#     'amonut': 5663,
#     'marketSum': 3172},
#    {'itemcode': '453870',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 인도니프티50',
#     'nowVal': 12375,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.36,
#     'nav': 12371.0,
#     'threeMonthEarnRate': 3.5177,
#     'quant': 332018,
#     'amonut': 4102,
#     'marketSum': 3168},
#    {'itemcode': '476550',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국30년국채프리미엄액티브(H)',
#     'nowVal': 9445,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.11,
#     'nav': 9448.0,
#     'threeMonthEarnRate': None,
#     'quant': 1091068,
#     'amonut': 10309,
#     'marketSum': 3140},
#    {'itemcode': '453810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 인도Nifty50',
#     'nowVal': 12635,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.28,
#     'nav': 12652.0,
#     'threeMonthEarnRate': 3.4397,
#     'quant': 397801,
#     'amonut': 5022,
#     'marketSum': 3140},
#    {'itemcode': '394670',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'nowVal': 6925,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.72,
#     'nav': 6942.0,
#     'threeMonthEarnRate': 14.6261,
#     'quant': 73436,
#     'amonut': 510,
#     'marketSum': 3138},
#    {'itemcode': '477080',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR CD금리액티브(합성)',
#     'nowVal': 100455,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.01,
#     'nav': 100427.0,
#     'threeMonthEarnRate': None,
#     'quant': 2048,
#     'amonut': 205,
#     'marketSum': 3114},
#    {'itemcode': '402970',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국배당다우존스',
#     'nowVal': 11535,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.35,
#     'nav': 11501.0,
#     'threeMonthEarnRate': 4.9867,
#     'quant': 170844,
#     'amonut': 1969,
#     'marketSum': 3091},
#    {'itemcode': '388420',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 비메모리반도체액티브',
#     'nowVal': 14340,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.42,
#     'nav': 14357.0,
#     'threeMonthEarnRate': 27.4203,
#     'quant': 357500,
#     'amonut': 5101,
#     'marketSum': 2920},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 13780,
#     'risefall': '2',
#     'changeVal': 165,
#     'changeRate': 1.21,
#     'nav': 13799.0,
#     'threeMonthEarnRate': 3.8441,
#     'quant': 173608,
#     'amonut': 2383,
#     'marketSum': 2861},
#    {'itemcode': '439860',
#     'etfTabCode': 6,
#     'itemname': 'KODEX ESG종합채권(A-이상)액티브',
#     'nowVal': 109110,
#     'risefall': '2',
#     'changeVal': 175,
#     'changeRate': 0.16,
#     'nav': 109091.0,
#     'threeMonthEarnRate': 0.9732,
#     'quant': 10,
#     'amonut': 1,
#     'marketSum': 2793},
#    {'itemcode': '439870',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채30년액티브',
#     'nowVal': 104735,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.09,
#     'nav': 104803.0,
#     'threeMonthEarnRate': -0.787,
#     'quant': 4683,
#     'amonut': 490,
#     'marketSum': 2778},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 34085,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.04,
#     'nav': 34218.0,
#     'threeMonthEarnRate': 13.3982,
#     'quant': 48380,
#     'amonut': 1642,
#     'marketSum': 2768},
#    {'itemcode': '472870',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국30년국채엔화노출(합성 H)',
#     'nowVal': 8620,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.12,
#     'nav': 8613.0,
#     'threeMonthEarnRate': -7.6478,
#     'quant': 439563,
#     'amonut': 3793,
#     'marketSum': 2728},
#    {'itemcode': '456610',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러SOFR금리액티브(합성)',
#     'nowVal': 53610,
#     'risefall': '2',
#     'changeVal': 245,
#     'changeRate': 0.46,
#     'nav': 53562.0,
#     'threeMonthEarnRate': 3.4706,
#     'quant': 7627,
#     'amonut': 408,
#     'marketSum': 2704},
#    {'itemcode': '474220',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10+10%프리미엄',
#     'nowVal': 11365,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.44,
#     'nav': 11338.0,
#     'threeMonthEarnRate': 10.1538,
#     'quant': 536213,
#     'amonut': 6093,
#     'marketSum': 2625},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 43565,
#     'risefall': '2',
#     'changeVal': 245,
#     'changeRate': 0.57,
#     'nav': 43533.0,
#     'threeMonthEarnRate': 21.6238,
#     'quant': 114769,
#     'amonut': 4983,
#     'marketSum': 2605},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'ACE 베트남VN30(합성)',
#     'nowVal': 19465,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.44,
#     'nav': 19648.0,
#     'threeMonthEarnRate': 4.0257,
#     'quant': 90212,
#     'amonut': 1757,
#     'marketSum': 2589},
#    {'itemcode': '457480',
#     'etfTabCode': 4,
#     'itemname': 'ACE 테슬라밸류체인액티브',
#     'nowVal': 10130,
#     'risefall': '5',
#     'changeVal': -315,
#     'changeRate': -3.02,
#     'nav': 10109.0,
#     'threeMonthEarnRate': 8.1822,
#     'quant': 869683,
#     'amonut': 8830,
#     'marketSum': 2558},
#    {'itemcode': '471990',
#     'etfTabCode': 2,
#     'itemname': 'KODEX AI반도체핵심장비',
#     'nowVal': 14040,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 1.41,
#     'nav': 14077.0,
#     'threeMonthEarnRate': 41.5499,
#     'quant': 1596619,
#     'amonut': 22267,
#     'marketSum': 2541},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 12585,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 1.12,
#     'nav': 12625.0,
#     'threeMonthEarnRate': 6.1588,
#     'quant': 10376,
#     'amonut': 130,
#     'marketSum': 2448},
#    {'itemcode': '241180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 일본니케이225',
#     'nowVal': 20400,
#     'risefall': '5',
#     'changeVal': -270,
#     'changeRate': -1.31,
#     'nav': 20336.0,
#     'threeMonthEarnRate': 6.2178,
#     'quant': 35311,
#     'amonut': 722,
#     'marketSum': 2432},
#    {'itemcode': '448880',
#     'etfTabCode': 6,
#     'itemname': 'ACE 24-12 회사채(AA-이상)액티브',
#     'nowVal': 104210,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 104210.0,
#     'threeMonthEarnRate': 0.964,
#     'quant': 3427,
#     'amonut': 357,
#     'marketSum': 2366},
#    {'itemcode': '451000',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 종합채권(AA-이상)액티브',
#     'nowVal': 107015,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.01,
#     'nav': 106963.0,
#     'threeMonthEarnRate': 0.6015,
#     'quant': 16,
#     'amonut': 1,
#     'marketSum': 2359},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 9290,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.6,
#     'nav': 9323.0,
#     'threeMonthEarnRate': 3.7523,
#     'quant': 23928,
#     'amonut': 221,
#     'marketSum': 2336},
#    {'itemcode': '451600',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 국고채30년액티브',
#     'nowVal': 100625,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.08,
#     'nav': 100594.0,
#     'threeMonthEarnRate': -0.6669,
#     'quant': 124,
#     'amonut': 12,
#     'marketSum': 2250},
#    {'itemcode': '449180',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500(H)',
#     'nowVal': 12215,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': 12216.0,
#     'threeMonthEarnRate': 4.3519,
#     'quant': 70704,
#     'amonut': 863,
#     'marketSum': 2241},
#    {'itemcode': '465580',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국빅테크TOP7 Plus',
#     'nowVal': 13310,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.38,
#     'nav': 13315.0,
#     'threeMonthEarnRate': 12.1353,
#     'quant': 219390,
#     'amonut': 2923,
#     'marketSum': 2229},
#    {'itemcode': '361580',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200TR',
#     'nowVal': 20510,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.22,
#     'nav': 20564.0,
#     'threeMonthEarnRate': 6.5607,
#     'quant': 29892,
#     'amonut': 611,
#     'marketSum': 2164},
#    {'itemcode': '456600',
#     'etfTabCode': 4,
#     'itemname': 'TIMEFOLIO 글로벌AI인공지능액티브',
#     'nowVal': 18795,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.34,
#     'nav': 18805.0,
#     'threeMonthEarnRate': 18.3929,
#     'quant': 171025,
#     'amonut': 3219,
#     'marketSum': 2161},
#    {'itemcode': '448290',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500TR(H)',
#     'nowVal': 12570,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.16,
#     'nav': 12566.0,
#     'threeMonthEarnRate': 4.3659,
#     'quant': 47027,
#     'amonut': 591,
#     'marketSum': 2156},
#    {'itemcode': '422420',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 2차전지액티브',
#     'nowVal': 9965,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.3,
#     'nav': 9993.0,
#     'threeMonthEarnRate': -0.6997,
#     'quant': 24062,
#     'amonut': 238,
#     'marketSum': 2154},
#    {'itemcode': '200250',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'nowVal': 23290,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.09,
#     'nav': 23174.0,
#     'threeMonthEarnRate': 3.5833,
#     'quant': 90877,
#     'amonut': 2110,
#     'marketSum': 2131},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SOL 200TR',
#     'nowVal': 13565,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.41,
#     'nav': 13587.0,
#     'threeMonthEarnRate': 6.336,
#     'quant': 149991,
#     'amonut': 2030,
#     'marketSum': 2096},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 8990,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.77,
#     'nav': 8979.0,
#     'threeMonthEarnRate': 12.4767,
#     'quant': 84793,
#     'amonut': 763,
#     'marketSum': 2095},
#    {'itemcode': '423920',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#     'nowVal': 22555,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.27,
#     'nav': 22389.0,
#     'threeMonthEarnRate': 23.9393,
#     'quant': 199817,
#     'amonut': 4491,
#     'marketSum': 2071},
#    {'itemcode': '411060',
#     'etfTabCode': 5,
#     'itemname': 'ACE KRX금현물',
#     'nowVal': 14610,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.41,
#     'nav': 14544.0,
#     'threeMonthEarnRate': 17.1026,
#     'quant': 116567,
#     'amonut': 1699,
#     'marketSum': 2060},
#    {'itemcode': '455860',
#     'etfTabCode': 2,
#     'itemname': 'SOL 2차전지소부장Fn',
#     'nowVal': 6820,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.15,
#     'nav': 6826.0,
#     'threeMonthEarnRate': -5.9393,
#     'quant': 127028,
#     'amonut': 859,
#     'marketSum': 2022},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 5860,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.51,
#     'nav': 5835.0,
#     'threeMonthEarnRate': 26.6666,
#     'quant': 1103304,
#     'amonut': 6499,
#     'marketSum': 2007},
#    {'itemcode': '473290',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 26-12 회사채(AA-이상)액티브',
#     'nowVal': 10240,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.1,
#     'nav': 10237.0,
#     'threeMonthEarnRate': 1.1369,
#     'quant': 27170,
#     'amonut': 278,
#     'marketSum': 1958},
#    {'itemcode': '464540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 25-03 회사채(AA-이상)액티브',
#     'nowVal': 50915,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 50889.0,
#     'threeMonthEarnRate': 0.9179,
#     'quant': 22707,
#     'amonut': 1156,
#     'marketSum': 1911},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 16000,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 16047.0,
#     'threeMonthEarnRate': 6.8447,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 1904},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 57515,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.05,
#     'nav': 57525.0,
#     'threeMonthEarnRate': 3.6699,
#     'quant': 17367,
#     'amonut': 998,
#     'marketSum': 1884},
#    {'itemcode': '471230',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채10년액티브',
#     'nowVal': 105160,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.11,
#     'nav': 105173.0,
#     'threeMonthEarnRate': -0.4125,
#     'quant': 3584,
#     'amonut': 376,
#     'marketSum': 1879},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 14790,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.1,
#     'nav': 14807.0,
#     'threeMonthEarnRate': 5.7623,
#     'quant': 26,
#     'amonut': 0,
#     'marketSum': 1878},
#    {'itemcode': '409820',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#     'nowVal': 9485,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.21,
#     'nav': 9518.0,
#     'threeMonthEarnRate': 3.4426,
#     'quant': 162907,
#     'amonut': 1547,
#     'marketSum': 1873},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 108865,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 108835.0,
#     'threeMonthEarnRate': 0.7451,
#     'quant': 2580,
#     'amonut': 280,
#     'marketSum': 1847},
#    {'itemcode': '395270',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn K-반도체',
#     'nowVal': 11985,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.04,
#     'nav': 11998.0,
#     'threeMonthEarnRate': 21.7603,
#     'quant': 136918,
#     'amonut': 1633,
#     'marketSum': 1834},
#    {'itemcode': '462330',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업레버리지',
#     'nowVal': 3830,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.13,
#     'nav': 3851.0,
#     'threeMonthEarnRate': -4.2554,
#     'quant': 977974,
#     'amonut': 3708,
#     'marketSum': 1823},
#    {'itemcode': '469820',
#     'etfTabCode': 6,
#     'itemname': 'SOL 24-12 회사채(AA-이상)액티브',
#     'nowVal': 51340,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.02,
#     'nav': 51343.0,
#     'threeMonthEarnRate': 0.9538,
#     'quant': 2285,
#     'amonut': 117,
#     'marketSum': 1801},
#    {'itemcode': '449190',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100(H)',
#     'nowVal': 14395,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.03,
#     'nav': 14402.0,
#     'threeMonthEarnRate': 2.5275,
#     'quant': 579311,
#     'amonut': 8347,
#     'marketSum': 1771},
#    {'itemcode': '463290',
#     'etfTabCode': 6,
#     'itemname': '1Q 단기금융채액티브',
#     'nowVal': 103425,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 103420.0,
#     'threeMonthEarnRate': 0.9123,
#     'quant': 2985,
#     'amonut': 308,
#     'marketSum': 1717},
#    {'itemcode': '445290',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-로봇액티브',
#     'nowVal': 14280,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.52,
#     'nav': 14302.0,
#     'threeMonthEarnRate': 1.0701,
#     'quant': 57476,
#     'amonut': 820,
#     'marketSum': 1692},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 18955,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.18,
#     'nav': 19013.0,
#     'threeMonthEarnRate': 8.3224,
#     'quant': 19139,
#     'amonut': 362,
#     'marketSum': 1668},
#    {'itemcode': '477050',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 머니마켓액티브',
#     'nowVal': 50265,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.03,
#     'nav': 50253.0,
#     'threeMonthEarnRate': None,
#     'quant': 31622,
#     'amonut': 1589,
#     'marketSum': 1655},
#    {'itemcode': '464230',
#     'etfTabCode': 6,
#     'itemname': '히어로즈 24-09 회사채(AA-이상)액티브',
#     'nowVal': 51250,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 51254.0,
#     'threeMonthEarnRate': 0.8541,
#     'quant': 12326,
#     'amonut': 631,
#     'marketSum': 1650},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER BBIG',
#     'nowVal': 6255,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.4,
#     'nav': 6268.0,
#     'threeMonthEarnRate': 0.9724,
#     'quant': 103394,
#     'amonut': 649,
#     'marketSum': 1626},
#    {'itemcode': '466920',
#     'etfTabCode': 2,
#     'itemname': 'SOL 조선TOP3플러스',
#     'nowVal': 10835,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.14,
#     'nav': 10827.0,
#     'threeMonthEarnRate': 22.8149,
#     'quant': 2620806,
#     'amonut': 28339,
#     'marketSum': 1614},
#    {'itemcode': '452360',
#     'etfTabCode': 4,
#     'itemname': 'SOL 미국배당다우존스(H)',
#     'nowVal': 10810,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10802.0,
#     'threeMonthEarnRate': 1.9243,
#     'quant': 72440,
#     'amonut': 782,
#     'marketSum': 1611},
#    {'itemcode': '451060',
#     'etfTabCode': 1,
#     'itemname': '1Q K200액티브',
#     'nowVal': 11880,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.34,
#     'nav': 11912.0,
#     'threeMonthEarnRate': 6.2359,
#     'quant': 368740,
#     'amonut': 4373,
#     'marketSum': 1586},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 12415,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12422.0,
#     'threeMonthEarnRate': 3.4583,
#     'quant': 33476,
#     'amonut': 415,
#     'marketSum': 1564},
#    {'itemcode': '363570',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#     'nowVal': 92270,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 0.11,
#     'nav': 92310.0,
#     'threeMonthEarnRate': 0.0162,
#     'quant': 21,
#     'amonut': 1,
#     'marketSum': 1560},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 14435,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.24,
#     'nav': 14436.0,
#     'threeMonthEarnRate': 13.1352,
#     'quant': 96398,
#     'amonut': 1392,
#     'marketSum': 1559},
#    {'itemcode': '438330',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 투자등급회사채액티브',
#     'nowVal': 109750,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.03,
#     'nav': 109775.0,
#     'threeMonthEarnRate': 1.1337,
#     'quant': 3043,
#     'amonut': 333,
#     'marketSum': 1541},
#    {'itemcode': '473330',
#     'etfTabCode': 6,
#     'itemname': 'SOL 미국30년국채커버드콜(합성)',
#     'nowVal': 9800,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.56,
#     'nav': 9786.0,
#     'threeMonthEarnRate': -0.8042,
#     'quant': 341355,
#     'amonut': 3343,
#     'marketSum': 1524},
#    {'itemcode': '325020',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 배당가치',
#     'nowVal': 14315,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 0.88,
#     'nav': 14331.0,
#     'threeMonthEarnRate': 3.11,
#     'quant': 8497,
#     'amonut': 121,
#     'marketSum': 1503},
#    {'itemcode': '261260',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물인버스2X',
#     'nowVal': 6030,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.66,
#     'nav': 6045.0,
#     'threeMonthEarnRate': -5.5988,
#     'quant': 420187,
#     'amonut': 2532,
#     'marketSum': 1498},
#    {'itemcode': '461950',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지핵심소재10 Fn',
#     'nowVal': 7375,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.14,
#     'nav': 7376.0,
#     'threeMonthEarnRate': -5.611,
#     'quant': 243698,
#     'amonut': 1780,
#     'marketSum': 1493},
#    {'itemcode': '451530',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국고채30년스트립액티브',
#     'nowVal': 49545,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 0.28,
#     'nav': 49599.0,
#     'threeMonthEarnRate': -1.2888,
#     'quant': 28724,
#     'amonut': 1425,
#     'marketSum': 1474},
#    {'itemcode': '471760',
#     'etfTabCode': 2,
#     'itemname': 'TIGER AI반도체핵심공정',
#     'nowVal': 13340,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 1.02,
#     'nav': 13359.0,
#     'threeMonthEarnRate': 37.8392,
#     'quant': 851391,
#     'amonut': 11242,
#     'marketSum': 1421},
#    {'itemcode': '244580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 바이오',
#     'nowVal': 8120,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.25,
#     'nav': 8160.0,
#     'threeMonthEarnRate': 11.6009,
#     'quant': 151198,
#     'amonut': 1222,
#     'marketSum': 1416},
#    {'itemcode': '401470',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-메타버스액티브',
#     'nowVal': 7290,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.07,
#     'nav': 7319.0,
#     'threeMonthEarnRate': 3.9914,
#     'quant': 46981,
#     'amonut': 342,
#     'marketSum': 1411},
#    {'itemcode': '476070',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 글로벌비만치료제TOP2 Plus',
#     'nowVal': 11945,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 1.19,
#     'nav': 11962.0,
#     'threeMonthEarnRate': None,
#     'quant': 286361,
#     'amonut': 3418,
#     'marketSum': 1410},
#    {'itemcode': '219480',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'nowVal': 23820,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.11,
#     'nav': 23824.0,
#     'threeMonthEarnRate': 3.9082,
#     'quant': 7108,
#     'amonut': 169,
#     'marketSum': 1405},
#    {'itemcode': '292560',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 일본엔선물',
#     'nowVal': 8410,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.18,
#     'nav': 8395.0,
#     'threeMonthEarnRate': -1.9779,
#     'quant': 251463,
#     'amonut': 2116,
#     'marketSum': 1396},
#    {'itemcode': '190620',
#     'etfTabCode': 6,
#     'itemname': 'ACE 단기통안채',
#     'nowVal': 101525,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.01,
#     'nav': 101522.0,
#     'threeMonthEarnRate': 0.7793,
#     'quant': 5167,
#     'amonut': 524,
#     'marketSum': 1384},
#    {'itemcode': '475080',
# ...
#     'nowVal': 5645,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -1.31,
#     'nav': 5696.0,
#     'threeMonthEarnRate': 8.5388,
#     'quant': 1452,
#     'amonut': 8,
#     'marketSum': 45},
#    {'itemcode': '413220',
#     'etfTabCode': 4,
#     'itemname': 'SOL 차이나태양광CSI(합성)',
#     'nowVal': 4460,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.11,
#     'nav': 4462.0,
#     'threeMonthEarnRate': 4.2007,
#     'quant': 2394,
#     'amonut': 10,
#     'marketSum': 45},
#    {'itemcode': '395760',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG성장주액티브',
#     'nowVal': 8900,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.39,
#     'nav': 8913.0,
#     'threeMonthEarnRate': 8.7463,
#     'quant': 9674,
#     'amonut': 85,
#     'marketSum': 45},
#    {'itemcode': '281990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 중소형고배당',
#     'nowVal': 11095,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.63,
#     'nav': 11118.0,
#     'threeMonthEarnRate': -1.7993,
#     'quant': 893,
#     'amonut': 9,
#     'marketSum': 44},
#    {'itemcode': '284980',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200금융',
#     'nowVal': 10565,
#     'risefall': '2',
#     'changeVal': 275,
#     'changeRate': 2.67,
#     'nav': 10582.0,
#     'threeMonthEarnRate': 7.0091,
#     'quant': 3925,
#     'amonut': 41,
#     'marketSum': 44},
#    {'itemcode': '244660',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 퀄리티Plus',
#     'nowVal': 8765,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.69,
#     'nav': 8771.0,
#     'threeMonthEarnRate': 0.3111,
#     'quant': 8,
#     'amonut': 0,
#     'marketSum': 44},
#    {'itemcode': '285000',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200IT',
#     'nowVal': 15470,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.36,
#     'nav': 15473.0,
#     'threeMonthEarnRate': 10.8115,
#     'quant': 653,
#     'amonut': 10,
#     'marketSum': 43},
#    {'itemcode': '238670',
#     'etfTabCode': 7,
#     'itemname': 'ARIRANG 스마트베타Quality채권혼합',
#     'nowVal': 10755,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.28,
#     'nav': 10758.0,
#     'threeMonthEarnRate': -0.2233,
#     'quant': 430,
#     'amonut': 4,
#     'marketSum': 43},
#    {'itemcode': '465620',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국빅테크TOP7 Plus인버스(합성)',
#     'nowVal': 14305,
#     'risefall': '5',
#     'changeVal': -60,
#     'changeRate': -0.42,
#     'nav': 14324.0,
#     'threeMonthEarnRate': -12.6748,
#     'quant': 1995,
#     'amonut': 28,
#     'marketSum': 43},
#    {'itemcode': '306520',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 200선물인버스',
#     'nowVal': 9530,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.21,
#     'nav': 9512.0,
#     'threeMonthEarnRate': -5.1639,
#     'quant': 215,
#     'amonut': 2,
#     'marketSum': 43},
#    {'itemcode': '285010',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200중공업',
#     'nowVal': 13335,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 1.21,
#     'nav': 13329.0,
#     'threeMonthEarnRate': 26.0886,
#     'quant': 2721,
#     'amonut': 36,
#     'marketSum': 43},
#    {'itemcode': '426330',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 미국ETF산업STOXX',
#     'nowVal': 12185,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 1.54,
#     'nav': 12197.0,
#     'threeMonthEarnRate': 2.6957,
#     'quant': 170,
#     'amonut': 2,
#     'marketSum': 43},
#    {'itemcode': '291630',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물레버리지',
#     'nowVal': 5815,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 5830.0,
#     'threeMonthEarnRate': 27.3822,
#     'quant': 39582,
#     'amonut': 227,
#     'marketSum': 42},
#    {'itemcode': '473380',
#     'etfTabCode': 2,
#     'itemname': 'HANARO K-메디테크',
#     'nowVal': 8365,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.83,
#     'nav': 8401.0,
#     'threeMonthEarnRate': -1.3214,
#     'quant': 11,
#     'amonut': 0,
#     'marketSum': 42},
#    {'itemcode': '295820',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200동일가중',
#     'nowVal': 10385,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 10483.0,
#     'threeMonthEarnRate': 3.6944,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 42},
#    {'itemcode': '284990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200에너지화학',
#     'nowVal': 8595,
#     'risefall': '2',
#     'changeVal': 105,
#     'changeRate': 1.24,
#     'nav': 8612.0,
#     'threeMonthEarnRate': -6.5802,
#     'quant': 1109,
#     'amonut': 9,
#     'marketSum': 41},
#    {'itemcode': '448510',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 글로벌신재생에너지MSCI(합성)',
#     'nowVal': 7405,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.89,
#     'nav': 7396.0,
#     'threeMonthEarnRate': 10.9599,
#     'quant': 1735,
#     'amonut': 12,
#     'marketSum': 41},
#    {'itemcode': '429870',
#     'etfTabCode': 7,
#     'itemname': '히어로즈 리츠이지스액티브',
#     'nowVal': 7370,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.07,
#     'nav': 7456.0,
#     'threeMonthEarnRate': 5.8341,
#     'quant': 13997,
#     'amonut': 102,
#     'marketSum': 41},
#    {'itemcode': '295000',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년',
#     'nowVal': 51840,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.15,
#     'nav': 51827.0,
#     'threeMonthEarnRate': -0.8714,
#     'quant': 143,
#     'amonut': 7,
#     'marketSum': 40},
#    {'itemcode': '445930',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 차이나A50커넥트레버리지MSCI(합성H)',
#     'nowVal': 8060,
#     'risefall': '5',
#     'changeVal': -190,
#     'changeRate': -2.3,
#     'nav': 8430.0,
#     'threeMonthEarnRate': 25.1896,
#     'quant': 702,
#     'amonut': 5,
#     'marketSum': 40},
#    {'itemcode': '256450',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 심천차이넥스트(합성)',
#     'nowVal': 8055,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 7994.0,
#     'threeMonthEarnRate': 13.7711,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '427120',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn플랫폼테마',
#     'nowVal': 6695,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.53,
#     'nav': 6708.0,
#     'threeMonthEarnRate': -5.3305,
#     'quant': 107,
#     'amonut': 0,
#     'marketSum': 40},
#    {'itemcode': '215620',
#     'etfTabCode': 2,
#     'itemname': 'HK S&P코리아로우볼',
#     'nowVal': 12745,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12836.0,
#     'threeMonthEarnRate': -0.1489,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 38},
#    {'itemcode': '147970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 모멘텀',
#     'nowVal': 27235,
#     'risefall': '2',
#     'changeVal': 200,
#     'changeRate': 0.74,
#     'nav': 27202.0,
#     'threeMonthEarnRate': 14.6376,
#     'quant': 946,
#     'amonut': 25,
#     'marketSum': 38},
#    {'itemcode': '407170',
#     'etfTabCode': 2,
#     'itemname': 'KCGI 스마트커머스액티브',
#     'nowVal': 7615,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.13,
#     'nav': 7620.0,
#     'threeMonthEarnRate': 9.3457,
#     'quant': 189,
#     'amonut': 1,
#     'marketSum': 38},
#    {'itemcode': '407300',
#     'etfTabCode': 2,
#     'itemname': 'HANARO Fn골프테마',
#     'nowVal': 5850,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.34,
#     'nav': 5890.0,
#     'threeMonthEarnRate': -4.7386,
#     'quant': 23,
#     'amonut': 0,
#     'marketSum': 38},
#    {'itemcode': '139310',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 금속선물(H)',
#     'nowVal': 6260,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.08,
#     'nav': 6325.0,
#     'threeMonthEarnRate': 15.5904,
#     'quant': 2134,
#     'amonut': 13,
#     'marketSum': 38},
#    {'itemcode': '243890',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200에너지화학레버리지',
#     'nowVal': 6765,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 1.42,
#     'nav': 6834.0,
#     'threeMonthEarnRate': -14.4872,
#     'quant': 49835,
#     'amonut': 332,
#     'marketSum': 36},
#    {'itemcode': '469790',
#     'etfTabCode': 2,
#     'itemname': 'KOSEF K-테크TOP10',
#     'nowVal': 11715,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.59,
#     'nav': 11710.0,
#     'threeMonthEarnRate': 8.5174,
#     'quant': 80,
#     'amonut': 0,
#     'marketSum': 35},
#    {'itemcode': '098560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 방송통신',
#     'nowVal': 6885,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.51,
#     'nav': 6881.0,
#     'threeMonthEarnRate': -5.3223,
#     'quant': 5940,
#     'amonut': 40,
#     'marketSum': 34},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SOL 차이나강소기업CSI500(합성 H)',
#     'nowVal': 4270,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.12,
#     'nav': 4263.0,
#     'threeMonthEarnRate': 7.8184,
#     'quant': 103,
#     'amonut': 0,
#     'marketSum': 34},
#    {'itemcode': '227560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 생활소비재',
#     'nowVal': 8455,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.18,
#     'nav': 8461.0,
#     'threeMonthEarnRate': 8.4645,
#     'quant': 1069,
#     'amonut': 9,
#     'marketSum': 34},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 8715,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.46,
#     'nav': 8753.0,
#     'threeMonthEarnRate': 0.4515,
#     'quant': 2673,
#     'amonut': 23,
#     'marketSum': 33},
#    {'itemcode': '472490',
#     'etfTabCode': 4,
#     'itemname': 'HANARO 미국애그테크',
#     'nowVal': 10970,
#     'risefall': '2',
#     'changeVal': 220,
#     'changeRate': 2.05,
#     'nav': 11027.0,
#     'threeMonthEarnRate': 8.7506,
#     'quant': 617,
#     'amonut': 6,
#     'marketSum': 33},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 6150,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.08,
#     'nav': 6138.0,
#     'threeMonthEarnRate': -11.9457,
#     'quant': 6656,
#     'amonut': 41,
#     'marketSum': 33},
#    {'itemcode': '397420',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물5년추종',
#     'nowVal': 49370,
#     'risefall': '2',
#     'changeVal': 115,
#     'changeRate': 0.23,
#     'nav': 49330.0,
#     'threeMonthEarnRate': -0.4045,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 33},
#    {'itemcode': '287300',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200건설',
#     'nowVal': 13380,
#     'risefall': '2',
#     'changeVal': 110,
#     'changeRate': 0.83,
#     'nav': 13372.0,
#     'threeMonthEarnRate': 1.0277,
#     'quant': 76,
#     'amonut': 1,
#     'marketSum': 32},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 6285,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.56,
#     'nav': 6325.0,
#     'threeMonthEarnRate': -7.476,
#     'quant': 104,
#     'amonut': 0,
#     'marketSum': 31},
#    {'itemcode': '267500',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 10430,
#     'risefall': '5',
#     'changeVal': -205,
#     'changeRate': -1.93,
#     'nav': 10635.0,
#     'threeMonthEarnRate': 7.3158,
#     'quant': 48,
#     'amonut': 0,
#     'marketSum': 31},
#    {'itemcode': '306530',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 코스닥150선물레버리지',
#     'nowVal': 11620,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -0.94,
#     'nav': 11729.0,
#     'threeMonthEarnRate': 26.8793,
#     'quant': 666,
#     'amonut': 7,
#     'marketSum': 30},
#    {'itemcode': '275750',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 3515,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.14,
#     'nav': 3506.0,
#     'threeMonthEarnRate': -12.2195,
#     'quant': 2432,
#     'amonut': 8,
#     'marketSum': 30},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'nowVal': 5270,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.19,
#     'nav': 5293.0,
#     'threeMonthEarnRate': -11.8928,
#     'quant': 1620,
#     'amonut': 8,
#     'marketSum': 29},
#    {'itemcode': '315270',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200커뮤니케이션서비스',
#     'nowVal': 17390,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.26,
#     'nav': 17392.0,
#     'threeMonthEarnRate': -2.3423,
#     'quant': 1256,
#     'amonut': 21,
#     'marketSum': 28},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 5310,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.38,
#     'nav': 5305.0,
#     'threeMonthEarnRate': -5.4126,
#     'quant': 1169,
#     'amonut': 6,
#     'marketSum': 28},
#    {'itemcode': '391590',
#     'etfTabCode': 4,
#     'itemname': 'ACE 미국스팩&IPO INDXX',
#     'nowVal': 5500,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.18,
#     'nav': 5477.0,
#     'threeMonthEarnRate': 4.5714,
#     'quant': 185,
#     'amonut': 1,
#     'marketSum': 28},
#    {'itemcode': '473500',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 글로벌전력반도체',
#     'nowVal': 9010,
#     'risefall': '2',
#     'changeVal': 135,
#     'changeRate': 1.52,
#     'nav': 9133.0,
#     'threeMonthEarnRate': -3.0585,
#     'quant': 147199,
#     'amonut': 1319,
#     'marketSum': 27},
#    {'itemcode': '145670',
#     'etfTabCode': 3,
#     'itemname': 'ACE 인버스',
#     'nowVal': 5110,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.39,
#     'nav': 5104.0,
#     'threeMonthEarnRate': -5.1757,
#     'quant': 2403,
#     'amonut': 12,
#     'marketSum': 26},
#    {'itemcode': '415920',
#     'etfTabCode': 5,
#     'itemname': 'ARIRANG 글로벌희토류전략자원기업MV',
#     'nowVal': 5090,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.2,
#     'nav': 5196.0,
#     'threeMonthEarnRate': 0.691,
#     'quant': 1308,
#     'amonut': 6,
#     'marketSum': 25},
#    {'itemcode': '252720',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'nowVal': 16610,
#     'risefall': '2',
#     'changeVal': 195,
#     'changeRate': 1.19,
#     'nav': 16617.0,
#     'threeMonthEarnRate': 6.2115,
#     'quant': 1163,
#     'amonut': 19,
#     'marketSum': 25},
#    {'itemcode': '299070',
#     'etfTabCode': 6,
#     'itemname': 'ACE 국채선물10년인버스',
#     'nowVal': 112955,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 112841.0,
#     'threeMonthEarnRate': 2.1847,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 23},
#    {'itemcode': '299080',
#     'etfTabCode': 6,
#     'itemname': 'ACE 국채선물3년인버스',
#     'nowVal': 110240,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 110169.0,
#     'threeMonthEarnRate': 1.5756,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 22},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 10660,
#     'risefall': '2',
#     'changeVal': 100,
#     'changeRate': 0.95,
#     'nav': 10659.0,
#     'threeMonthEarnRate': 0.1232,
#     'quant': 32,
#     'amonut': 0,
#     'marketSum': 21},
#    {'itemcode': '412560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER BBIG레버리지',
#     'nowVal': 2210,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 1.14,
#     'nav': 2226.0,
#     'threeMonthEarnRate': -0.9071,
#     'quant': 4169,
#     'amonut': 9,
#     'marketSum': 19},
#    {'itemcode': '252730',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀로우볼',
#     'nowVal': 16285,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.46,
#     'nav': 16300.0,
#     'threeMonthEarnRate': 6.8204,
#     'quant': 12,
#     'amonut': 0,
#     'marketSum': 16},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 6415,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.08,
#     'nav': 6415.0,
#     'threeMonthEarnRate': 8.2995,
#     'quant': 2140,
#     'amonut': 13,
#     'marketSum': 14},
#    {'itemcode': '315480',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200커뮤니케이션서비스',
#     'nowVal': 10965,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.23,
#     'nav': 10969.0,
#     'threeMonthEarnRate': -1.9011,
#     'quant': 119,
#     'amonut': 1,
#     'marketSum': 13},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 12495,
#     'risefall': '2',
#     'changeVal': 125,
#     'changeRate': 1.01,
#     'nav': 12504.0,
#     'threeMonthEarnRate': 8.0443,
#     'quant': 149,
#     'amonut': 1,
#     'marketSum': 10}]}}

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받기
etf_json = response.json()
etf_json["result"]
# Out:
# {'etfItemList': [{'itemcode': '459580',
#    'etfTabCode': 6,
#    'itemname': 'KODEX CD금리액티브(합성)',
#    'nowVal': 1035155,
#    'risefall': '2',
#    'changeVal': 100,
#    'changeRate': 0.01,
#    'nav': 1035156.0,
#    'threeMonthEarnRate': 0.884,
#    'quant': 344339,
#    'amonut': 356445,
#    'marketSum': 83168},
#   {'itemcode': '357870',
#    'etfTabCode': 6,
#    'itemname': 'TIGER CD금리투자KIS(합성)',
#    'nowVal': 54265,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.01,
#    'nav': 54258.0,
#    'threeMonthEarnRate': 0.8456,
#    'quant': 132995,
#    'amonut': 7216,
#    'marketSum': 73403},
#   {'itemcode': '069500',
#    'etfTabCode': 1,
#    'itemname': 'KODEX 200',
#    'nowVal': 37460,
#    'risefall': '2',
#    'changeVal': 130,
#    'changeRate': 0.35,
#    'nav': 37556.0,
#    'threeMonthEarnRate': 6.584,
#    'quant': 1895070,
#    'amonut': 70864,
#    'marketSum': 63813},
#   {'itemcode': '423160',
#    'etfTabCode': 6,
#    'itemname': 'KODEX KOFR금리액티브(합성)',
#    'nowVal': 106685,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 106678.0,
#    'threeMonthEarnRate': 0.8841,
#    'quant': 609048,
#    'amonut': 64976,
#    'marketSum': 52336},
#   {'itemcode': '449170',
#    'etfTabCode': 6,
#    'itemname': 'TIGER KOFR금리액티브(합성)',
#    'nowVal': 105225,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.01,
#    'nav': 105221.0,
#    'threeMonthEarnRate': 0.8869,
#    'quant': 42740,
#    'amonut': 4497,
#    'marketSum': 37320},
#   {'itemcode': '360750',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국S&P500',
#    'nowVal': 17625,
#    'risefall': '2',
#    'changeVal': 85,
#    'changeRate': 0.48,
#    'nav': 17593.0,
#    'threeMonthEarnRate': 7.2586,
#    'quant': 1144322,
#    'amonut': 20162,
#    'marketSum': 32474},
#   {'itemcode': '133690',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국나스닥100',
#    'nowVal': 109905,
#    'risefall': '2',
#    'changeVal': 485,
#    'changeRate': 0.44,
#    'nav': 109731.0,
#    'threeMonthEarnRate': 5.4041,
#    'quant': 114739,
#    'amonut': 12607,
#    'marketSum': 31455},
#   {'itemcode': '273130',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 종합채권(AA-이상)액티브',
#    'nowVal': 109885,
#    'risefall': '5',
#    'changeVal': -50,
#    'changeRate': -0.05,
#    'nav': 109920.0,
#    'threeMonthEarnRate': 0.6592,
#    'quant': 7426,
#    'amonut': 815,
#    'marketSum': 28325},
#   {'itemcode': '465680',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 24-12 은행채(AA+이상)액티브',
#    'nowVal': 10280,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 10280.0,
#    'threeMonthEarnRate': 0.8832,
#    'quant': 49967,
#    'amonut': 513,
#    'marketSum': 26173},
#   {'itemcode': '381180',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국필라델피아반도체나스닥',
#    'nowVal': 17315,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 17250.0,
#    'threeMonthEarnRate': 13.3254,
#    'quant': 1316211,
#    'amonut': 22768,
#    'marketSum': 23704},
#   {'itemcode': '102110',
#    'etfTabCode': 1,
#    'itemname': 'TIGER 200',
#    'nowVal': 37525,
#    'risefall': '2',
#    'changeVal': 130,
#    'changeRate': 0.35,
#    'nav': 37620.0,
#    'threeMonthEarnRate': 6.5263,
#    'quant': 827801,
#    'amonut': 31001,
#    'marketSum': 23153},
#   {'itemcode': '122630',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 레버리지',
#    'nowVal': 19955,
#    'risefall': '2',
#    'changeVal': 150,
#    'changeRate': 0.76,
#    'nav': 20174.0,
#    'threeMonthEarnRate': 10.9213,
#    'quant': 10526173,
#    'amonut': 209148,
#    'marketSum': 21561},
#   {'itemcode': '278530',
#    'etfTabCode': 1,
#    'itemname': 'KODEX 200TR',
#    'nowVal': 13030,
#    'risefall': '2',
#    'changeVal': 55,
#    'changeRate': 0.42,
#    'nav': 13060.0,
#    'threeMonthEarnRate': 6.396,
#    'quant': 191363,
#    'amonut': 2486,
#    'marketSum': 21519},
#   {'itemcode': '381170',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국테크TOP10 INDXX',
#    'nowVal': 18285,
#    'risefall': '2',
#    'changeVal': 50,
#    'changeRate': 0.27,
#    'nav': 18250.0,
#    'threeMonthEarnRate': 10.3813,
#    'quant': 883642,
#    'amonut': 16153,
#    'marketSum': 21256},
#   {'itemcode': '371460',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나전기차SOLACTIVE',
#    'nowVal': 8120,
#    'risefall': '5',
#    'changeVal': -120,
#    'changeRate': -1.46,
#    'nav': 8100.0,
#    'threeMonthEarnRate': 20.6442,
#    'quant': 1744008,
#    'amonut': 14250,
#    'marketSum': 20505},
#   {'itemcode': '455890',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 머니마켓액티브',
#    'nowVal': 52185,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.01,
#    'nav': 52182.0,
#    'threeMonthEarnRate': 0.9772,
#    'quant': 222371,
#    'amonut': 11604,
#    'marketSum': 15700},
#   {'itemcode': '252670',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 200선물인버스2X',
#    'nowVal': 1991,
#    'risefall': '5',
#    'changeVal': -14,
#    'changeRate': -0.7,
#    'nav': 1992.0,
#    'threeMonthEarnRate': -12.0615,
#    'quant': 147938145,
#    'amonut': 295905,
#    'marketSum': 13407},
#   {'itemcode': '102780',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 삼성그룹',
#    'nowVal': 9685,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.47,
#    'nav': 9706.0,
#    'threeMonthEarnRate': 7.0516,
#    'quant': 514085,
#    'amonut': 4969,
#    'marketSum': 12988},
#   {'itemcode': '148020',
#    'etfTabCode': 1,
#    'itemname': 'KBSTAR 200',
#    'nowVal': 37715,
#    'risefall': '2',
#    'changeVal': 140,
#    'changeRate': 0.37,
#    'nav': 37802.0,
#    'threeMonthEarnRate': 6.5473,
#    'quant': 162115,
#    'amonut': 6099,
#    'marketSum': 12842},
#   {'itemcode': '305540',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 2차전지테마',
#    'nowVal': 23530,
#    'risefall': '2',
#    'changeVal': 55,
#    'changeRate': 0.23,
#    'nav': 23585.0,
#    'threeMonthEarnRate': -1.8358,
#    'quant': 228754,
#    'amonut': 5352,
#    'marketSum': 12765},
#   {'itemcode': '305720',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 2차전지산업',
#    'nowVal': 20055,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.02,
#    'nav': 20093.0,
#    'threeMonthEarnRate': -0.5701,
#    'quant': 542173,
#    'amonut': 10821,
#    'marketSum': 12735},
#   {'itemcode': '315930',
#    'etfTabCode': 2,
#    'itemname': 'KODEX Top5PlusTR',
#    'nowVal': 23145,
#    'risefall': '2',
#    'changeVal': 70,
#    'changeRate': 0.3,
#    'nav': 23143.0,
#    'threeMonthEarnRate': 10.698,
#    'quant': 14083,
#    'amonut': 325,
#    'marketSum': 12730},
#   {'itemcode': '470260',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 24-12 금융채(AA-이상)',
#    'nowVal': 51160,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.02,
#    'nav': 51168.0,
#    'threeMonthEarnRate': 0.8975,
#    'quant': 830,
#    'amonut': 42,
#    'marketSum': 12634},
#   {'itemcode': '214980',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 단기채권PLUS',
#    'nowVal': 110435,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.03,
#    'nav': 110436.0,
#    'threeMonthEarnRate': 0.808,
#    'quant': 7563,
#    'amonut': 835,
#    'marketSum': 12089},
#   {'itemcode': '292150',
#    'etfTabCode': 2,
#    'itemname': 'TIGER TOP10',
#    'nowVal': 12425,
#    'risefall': '5',
#    'changeVal': -25,
#    'changeRate': -0.2,
#    'nav': 12465.0,
#    'threeMonthEarnRate': 8.3079,
#    'quant': 71926,
#    'amonut': 893,
#    'marketSum': 11940},
#   {'itemcode': '453850',
#    'etfTabCode': 6,
#    'itemname': 'ACE 미국30년국채액티브(H)',
#    'nowVal': 8265,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 8276.0,
#    'threeMonthEarnRate': -4.5282,
#    'quant': 1450063,
#    'amonut': 11998,
#    'marketSum': 11571},
#   {'itemcode': '310970',
#    'etfTabCode': 1,
#    'itemname': 'TIGER MSCI Korea TR',
#    'nowVal': 16035,
#    'risefall': '2',
#    'changeVal': 75,
#    'changeRate': 0.47,
#    'nav': 16064.0,
#    'threeMonthEarnRate': 6.6132,
#    'quant': 5115,
#    'amonut': 81,
#    'marketSum': 11401},
#   {'itemcode': '385540',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 종합채권(A-이상)액티브',
#    'nowVal': 101800,
#    'risefall': '5',
#    'changeVal': -25,
#    'changeRate': -0.02,
#    'nav': 101810.0,
#    'threeMonthEarnRate': 0.4934,
#    'quant': 2146,
#    'amonut': 218,
#    'marketSum': 11296},
#   {'itemcode': '233740',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 코스닥150레버리지',
#    'nowVal': 11830,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.17,
#    'nav': 11925.0,
#    'threeMonthEarnRate': 25.1059,
#    'quant': 16371002,
#    'amonut': 191048,
#    'marketSum': 10955},
#   {'itemcode': '379800',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국S&P500TR',
#    'nowVal': 16060,
#    'risefall': '2',
#    'changeVal': 80,
#    'changeRate': 0.5,
#    'nav': 16031.0,
#    'threeMonthEarnRate': 7.3203,
#    'quant': 734023,
#    'amonut': 11792,
#    'marketSum': 10632},
#   {'itemcode': '360200',
#    'etfTabCode': 4,
#    'itemname': 'ACE 미국S&P500',
#    'nowVal': 17830,
#    'risefall': '2',
#    'changeVal': 90,
#    'changeRate': 0.51,
#    'nav': 17792.0,
#    'threeMonthEarnRate': 7.3005,
#    'quant': 173809,
#    'amonut': 3097,
#    'marketSum': 9735},
#   {'itemcode': '229200',
#    'etfTabCode': 1,
#    'itemname': 'KODEX 코스닥150',
#    'nowVal': 14310,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.14,
#    'nav': 14377.0,
#    'threeMonthEarnRate': 12.4577,
#    'quant': 4109473,
#    'amonut': 58396,
#    'marketSum': 9022},
#   {'itemcode': '396500',
#    'etfTabCode': 2,
#    'itemname': 'TIGER Fn반도체TOP10',
#    'nowVal': 13210,
#    'risefall': '2',
#    'changeVal': 115,
#    'changeRate': 0.88,
#    'nav': 13188.0,
#    'threeMonthEarnRate': 27.5197,
#    'quant': 1140448,
#    'amonut': 14953,
#    'marketSum': 8712},
#   {'itemcode': '458730',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국배당다우존스',
#    'nowVal': 11390,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.4,
#    'nav': 11360.0,
#    'threeMonthEarnRate': 4.8715,
#    'quant': 654279,
#    'amonut': 7452,
#    'marketSum': 8400},
#   {'itemcode': '447820',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 24-10 회사채(A+이상)액티브',
#    'nowVal': 54865,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.02,
#    'nav': 54855.0,
#    'threeMonthEarnRate': 0.9384,
#    'quant': 26882,
#    'amonut': 1474,
#    'marketSum': 8117},
#   {'itemcode': '436140',
#    'etfTabCode': 6,
#    'itemname': 'SOL 종합채권(AA-이상)액티브',
#    'nowVal': 106380,
#    'risefall': '2',
#    'changeVal': 75,
#    'changeRate': 0.07,
#    'nav': 106366.0,
#    'threeMonthEarnRate': 0.4251,
#    'quant': 3,
#    'amonut': 0,
#    'marketSum': 8115},
#   {'itemcode': '367380',
#    'etfTabCode': 4,
#    'itemname': 'ACE 미국나스닥100',
#    'nowVal': 18890,
#    'risefall': '2',
#    'changeVal': 70,
#    'changeRate': 0.37,
#    'nav': 18859.0,
#    'threeMonthEarnRate': 5.5169,
#    'quant': 130338,
#    'amonut': 2462,
#    'marketSum': 7764},
#   {'itemcode': '379810',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국나스닥100TR',
#    'nowVal': 16420,
#    'risefall': '2',
#    'changeVal': 75,
#    'changeRate': 0.46,
#    'nav': 16396.0,
#    'threeMonthEarnRate': 5.4516,
#    'quant': 252343,
#    'amonut': 4144,
#    'marketSum': 7758},
#   {'itemcode': '139260',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200 IT',
#    'nowVal': 34515,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.13,
#    'nav': 34519.0,
#    'threeMonthEarnRate': 10.1665,
#    'quant': 22174,
#    'amonut': 763,
#    'marketSum': 7655},
#   {'itemcode': '157450',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 단기통안채',
#    'nowVal': 106830,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 106843.0,
#    'threeMonthEarnRate': 0.7402,
#    'quant': 6481,
#    'amonut': 692,
#    'marketSum': 7536},
#   {'itemcode': '091160',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 반도체',
#    'nowVal': 41995,
#    'risefall': '2',
#    'changeVal': 160,
#    'changeRate': 0.38,
#    'nav': 42012.0,
#    'threeMonthEarnRate': 22.1995,
#    'quant': 264676,
#    'amonut': 11055,
#    'marketSum': 7433},
#   {'itemcode': '153130',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 단기채권',
#    'nowVal': 109500,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 109510.0,
#    'threeMonthEarnRate': 0.7591,
#    'quant': 8365,
#    'amonut': 916,
#    'marketSum': 7240},
#   {'itemcode': '356540',
#    'etfTabCode': 6,
#    'itemname': 'ACE 종합채권(AA-이상)KIS액티브',
#    'nowVal': 100395,
#    'risefall': '5',
#    'changeVal': -55,
#    'changeRate': -0.05,
#    'nav': 100384.0,
#    'threeMonthEarnRate': 0.5354,
#    'quant': 272,
#    'amonut': 27,
#    'marketSum': 7139},
#   {'itemcode': '294400',
#    'etfTabCode': 1,
#    'itemname': 'KOSEF 200TR',
#    'nowVal': 47390,
#    'risefall': '2',
#    'changeVal': 160,
#    'changeRate': 0.34,
#    'nav': 47507.0,
#    'threeMonthEarnRate': 6.5298,
#    'quant': 20653,
#    'amonut': 977,
#    'marketSum': 7037},
#   {'itemcode': '462010',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 2차전지소재Fn',
#    'nowVal': 7135,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.07,
#    'nav': 7145.0,
#    'threeMonthEarnRate': -4.5327,
#    'quant': 496471,
#    'amonut': 3516,
#    'marketSum': 6839},
#   {'itemcode': '453540',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 25-10 회사채(A+이상)액티브',
#    'nowVal': 52660,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.01,
#    'nav': 52651.0,
#    'threeMonthEarnRate': 0.9974,
#    'quant': 83773,
#    'amonut': 4411,
#    'marketSum': 6778},
#   {'itemcode': '152100',
#    'etfTabCode': 1,
#    'itemname': 'ARIRANG 200',
#    'nowVal': 38020,
#    'risefall': '2',
#    'changeVal': 110,
#    'changeRate': 0.29,
#    'nav': 38113.0,
#    'threeMonthEarnRate': 6.6385,
#    'quant': 43914,
#    'amonut': 1666,
#    'marketSum': 6558},
#   {'itemcode': '091180',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 자동차',
#    'nowVal': 20835,
#    'risefall': '2',
#    'changeVal': 100,
#    'changeRate': 0.48,
#    'nav': 20861.0,
#    'threeMonthEarnRate': 0.9936,
#    'quant': 236979,
#    'amonut': 4925,
#    'marketSum': 6219},
#   {'itemcode': '458760',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국배당+7%프리미엄다우존스',
#    'nowVal': 10270,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.29,
#    'nav': 10243.0,
#    'threeMonthEarnRate': 3.8223,
#    'quant': 677843,
#    'amonut': 6956,
#    'marketSum': 6208},
#   {'itemcode': '371160',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나항셍테크',
#    'nowVal': 5850,
#    'risefall': '5',
#    'changeVal': -40,
#    'changeRate': -0.68,
#    'nav': 5844.0,
#    'threeMonthEarnRate': 26.803,
#    'quant': 2169851,
#    'amonut': 12844,
#    'marketSum': 6122},
#   {'itemcode': '475630',
#    'etfTabCode': 7,
#    'itemname': 'TIGER 1년은행양도성예금증서액티브(합성)',
#    'nowVal': 1009780,
#    'risefall': '2',
#    'changeVal': 100,
#    'changeRate': 0.01,
#    'nav': 1009779.0,
#    'threeMonthEarnRate': 0.8555,
#    'quant': 20579,
#    'amonut': 20780,
#    'marketSum': 6016},
#   {'itemcode': '272580',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 단기채권액티브',
#    'nowVal': 53810,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.02,
#    'nav': 53798.0,
#    'threeMonthEarnRate': 0.834,
#    'quant': 7297,
#    'amonut': 392,
#    'marketSum': 5904},
#   {'itemcode': '114800',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 인버스',
#    'nowVal': 4110,
#    'risefall': '5',
#    'changeVal': -10,
#    'changeRate': -0.24,
#    'nav': 4106.0,
#    'threeMonthEarnRate': -5.5046,
#    'quant': 20893689,
#    'amonut': 85987,
#    'marketSum': 5766},
#   {'itemcode': '329750',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 미국달러단기채권액티브',
#    'nowVal': 12065,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.37,
#    'nav': 12053.0,
#    'threeMonthEarnRate': 3.2646,
#    'quant': 69472,
#    'amonut': 837,
#    'marketSum': 5674},
#   {'itemcode': '196230',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 단기통안채',
#    'nowVal': 111460,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.01,
#    'nav': 111473.0,
#    'threeMonthEarnRate': 0.7412,
#    'quant': 37299,
#    'amonut': 4157,
#    'marketSum': 5352},
#   {'itemcode': '314250',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국빅테크10(H)',
#    'nowVal': 36840,
#    'risefall': '5',
#    'changeVal': -15,
#    'changeRate': -0.04,
#    'nav': 36771.0,
#    'threeMonthEarnRate': 5.9356,
#    'quant': 80114,
#    'amonut': 2945,
#    'marketSum': 5345},
#   {'itemcode': '293180',
#    'etfTabCode': 1,
#    'itemname': 'HANARO 200',
#    'nowVal': 37555,
#    'risefall': '2',
#    'changeVal': 150,
#    'changeRate': 0.4,
#    'nav': 37663.0,
#    'threeMonthEarnRate': 6.3911,
#    'quant': 15666,
#    'amonut': 587,
#    'marketSum': 5333},
#   {'itemcode': '446720',
#    'etfTabCode': 4,
#    'itemname': 'SOL 미국배당다우존스',
#    'nowVal': 10455,
#    'risefall': '2',
#    'changeVal': 50,
#    'changeRate': 0.48,
#    'nav': 10420.0,
#    'threeMonthEarnRate': 4.9102,
#    'quant': 263660,
#    'amonut': 2754,
#    'marketSum': 5228},
#   {'itemcode': '451540',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 종합채권(AA-이상)액티브',
#    'nowVal': 52530,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.02,
#    'nav': 52533.0,
#    'threeMonthEarnRate': 0.4878,
#    'quant': 3745,
#    'amonut': 196,
#    'marketSum': 4982},
#   {'itemcode': '148070',
#    'etfTabCode': 6,
#    'itemname': 'KOSEF 국고채10년',
#    'nowVal': 110930,
#    'risefall': '5',
#    'changeVal': -70,
#    'changeRate': -0.06,
#    'nav': 110947.0,
#    'threeMonthEarnRate': -0.1979,
#    'quant': 8886,
#    'amonut': 985,
#    'marketSum': 4892},
#   {'itemcode': '105190',
#    'etfTabCode': 1,
#    'itemname': 'ACE 200',
#    'nowVal': 37730,
#    'risefall': '2',
#    'changeVal': 85,
#    'changeRate': 0.23,
#    'nav': 37826.0,
#    'threeMonthEarnRate': 6.5344,
#    'quant': 9785,
#    'amonut': 368,
#    'marketSum': 4735},
#   {'itemcode': '368590',
#    'etfTabCode': 4,
#    'itemname': 'KBSTAR 미국나스닥100',
#    'nowVal': 18280,
#    'risefall': '2',
#    'changeVal': 80,
#    'changeRate': 0.44,
#    'nav': 18252.0,
#    'threeMonthEarnRate': 5.4033,
#    'quant': 114464,
#    'amonut': 2092,
#    'marketSum': 4661},
#   {'itemcode': '469830',
#    'etfTabCode': 6,
#    'itemname': 'SOL 초단기채권액티브',
#    'nowVal': 51160,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 51159.0,
#    'threeMonthEarnRate': 0.9969,
#    'quant': 136462,
#    'amonut': 6981,
#    'marketSum': 4636},
#   {'itemcode': '385560',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR KIS국고채30년Enhanced',
#    'nowVal': 70185,
#    'risefall': '2',
#    'changeVal': 125,
#    'changeRate': 0.18,
#    'nav': 70140.0,
#    'threeMonthEarnRate': -1.1792,
#    'quant': 32203,
#    'amonut': 2259,
#    'marketSum': 4555},
#   {'itemcode': '365780',
#    'etfTabCode': 6,
#    'itemname': 'ACE 국고채10년',
#    'nowVal': 87165,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.02,
#    'nav': 87190.0,
#    'threeMonthEarnRate': -0.326,
#    'quant': 4765,
#    'amonut': 415,
#    'marketSum': 4375},
#   {'itemcode': '329200',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 리츠부동산인프라',
#    'nowVal': 4500,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.78,
#    'nav': 4511.0,
#    'threeMonthEarnRate': 4.7138,
#    'quant': 800513,
#    'amonut': 3591,
#    'marketSum': 4343},
#   {'itemcode': '278540',
#    'etfTabCode': 1,
#    'itemname': 'KODEX MSCI Korea TR',
#    'nowVal': 12740,
#    'risefall': '2',
#    'changeVal': 25,
#    'changeRate': 0.2,
#    'nav': 12797.0,
#    'threeMonthEarnRate': 7.2091,
#    'quant': 1005,
#    'amonut': 12,
#    'marketSum': 4230},
#   {'itemcode': '455850',
#    'etfTabCode': 2,
#    'itemname': 'SOL AI반도체소부장',
#    'nowVal': 16490,
#    'risefall': '2',
#    'changeVal': 140,
#    'changeRate': 0.86,
#    'nav': 16518.0,
#    'threeMonthEarnRate': 29.7207,
#    'quant': 499803,
#    'amonut': 8176,
#    'marketSum': 4106},
#   {'itemcode': '481050',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 1년은행양도성예금증서+액티브(합성)',
#    'nowVal': 1002305,
#    'risefall': '2',
#    'changeVal': 95,
#    'changeRate': 0.01,
#    'nav': 1002304.0,
#    'threeMonthEarnRate': None,
#    'quant': 5264,
#    'amonut': 5276,
#    'marketSum': 3959},
#   {'itemcode': '251340',
#    'etfTabCode': 3,
#    'itemname': 'KODEX 코스닥150선물인버스',
#    'nowVal': 3405,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.15,
#    'nav': 3422.0,
#    'threeMonthEarnRate': -12.2266,
#    'quant': 20703658,
#    'amonut': 71040,
#    'marketSum': 3943},
#   {'itemcode': '458250',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 미국30년국채스트립액티브(합성 H)',
#    'nowVal': 42010,
#    'risefall': '2',
#    'changeVal': 140,
#    'changeRate': 0.33,
#    'nav': 42147.0,
#    'threeMonthEarnRate': -7.9781,
#    'quant': 150052,
#    'amonut': 6308,
#    'marketSum': 3883},
#   {'itemcode': '091170',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 은행',
#    'nowVal': 8120,
#    'risefall': '2',
#    'changeVal': 220,
#    'changeRate': 2.78,
#    'nav': 8130.0,
#    'threeMonthEarnRate': 7.8645,
#    'quant': 804029,
#    'amonut': 6498,
#    'marketSum': 3861},
#   {'itemcode': '114260',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 국고채3년',
#    'nowVal': 59485,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.03,
#    'nav': 59444.0,
#    'threeMonthEarnRate': 0.2867,
#    'quant': 2383,
#    'amonut': 141,
#    'marketSum': 3832},
#   {'itemcode': '476810',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 25-11 은행채(AA-이상)PLUS액티브',
#    'nowVal': 10075,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.05,
#    'nav': 10080.0,
#    'threeMonthEarnRate': None,
#    'quant': 1386,
#    'amonut': 13,
#    'marketSum': 3767},
#   {'itemcode': '390390',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국반도체MV',
#    'nowVal': 20660,
#    'risefall': '5',
#    'changeVal': -30,
#    'changeRate': -0.14,
#    'nav': 20602.0,
#    'threeMonthEarnRate': 17.9925,
#    'quant': 402333,
#    'amonut': 8303,
#    'marketSum': 3688},
#   {'itemcode': '379780',
#    'etfTabCode': 4,
#    'itemname': 'KBSTAR 미국S&P500',
#    'nowVal': 15415,
#    'risefall': '2',
#    'changeVal': 70,
#    'changeRate': 0.46,
#    'nav': 15391.0,
#    'threeMonthEarnRate': 7.3602,
#    'quant': 127845,
#    'amonut': 1970,
#    'marketSum': 3684},
#   {'itemcode': '461460',
#    'etfTabCode': 6,
#    'itemname': 'ARIRANG 국고채10년액티브',
#    'nowVal': 51840,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.04,
#    'nav': 51827.0,
#    'threeMonthEarnRate': -0.3174,
#    'quant': 24,
#    'amonut': 1,
#    'marketSum': 3680},
#   {'itemcode': '476450',
#    'etfTabCode': 6,
#    'itemname': '히어로즈 머니마켓액티브',
#    'nowVal': 50430,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.02,
#    'nav': 50427.0,
#    'threeMonthEarnRate': None,
#    'quant': 39598,
#    'amonut': 1996,
#    'marketSum': 3674},
#   {'itemcode': '226490',
#    'etfTabCode': 1,
#    'itemname': 'KODEX 코스피',
#    'nowVal': 27890,
#    'risefall': '2',
#    'changeVal': 120,
#    'changeRate': 0.43,
#    'nav': 27895.0,
#    'threeMonthEarnRate': 5.5652,
#    'quant': 173151,
#    'amonut': 4814,
#    'marketSum': 3668},
#   {'itemcode': '441680',
#    'etfTabCode': 7,
#    'itemname': 'TIGER 미국나스닥100커버드콜(합성)',
#    'nowVal': 10365,
#    'risefall': '2',
#    'changeVal': 40,
#    'changeRate': 0.39,
#    'nav': 10357.0,
#    'threeMonthEarnRate': 3.9359,
#    'quant': 287305,
#    'amonut': 2972,
#    'marketSum': 3612},
#   {'itemcode': '364980',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 2차전지TOP10',
#    'nowVal': 13055,
#    'risefall': '2',
#    'changeVal': 25,
#    'changeRate': 0.19,
#    'nav': 13099.0,
#    'threeMonthEarnRate': 1.4797,
#    'quant': 894388,
#    'amonut': 11630,
#    'marketSum': 3525},
#   {'itemcode': '069660',
#    'etfTabCode': 1,
#    'itemname': 'KOSEF 200',
#    'nowVal': 37425,
#    'risefall': '2',
#    'changeVal': 130,
#    'changeRate': 0.35,
#    'nav': 37516.0,
#    'threeMonthEarnRate': 6.554,
#    'quant': 40247,
#    'amonut': 1502,
#    'marketSum': 3499},
#   {'itemcode': '455030',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 미국달러SOFR금리액티브(합성)',
#    'nowVal': 11105,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.18,
#    'nav': 11096.0,
#    'threeMonthEarnRate': 4.1823,
#    'quant': 40407,
#    'amonut': 449,
#    'marketSum': 3458},
#   {'itemcode': '446770',
#    'etfTabCode': 4,
#    'itemname': 'ACE 글로벌반도체TOP4 Plus SOLACTIVE',
#    'nowVal': 22365,
#    'risefall': '5',
#    'changeVal': -175,
#    'changeRate': -0.78,
#    'nav': 22278.0,
#    'threeMonthEarnRate': 17.2675,
#    'quant': 216591,
#    'amonut': 4839,
#    'marketSum': 3433},
#   {'itemcode': '273140',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 단기변동금리부채권액티브',
#    'nowVal': 110510,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.02,
#    'nav': 110507.0,
#    'threeMonthEarnRate': 0.7936,
#    'quant': 4283,
#    'amonut': 473,
#    'marketSum': 3355},
#   {'itemcode': '251350',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 선진국MSCI World',
#    'nowVal': 26685,
#    'risefall': '2',
#    'changeVal': 25,
#    'changeRate': 0.09,
#    'nav': 26623.0,
#    'threeMonthEarnRate': 7.691,
#    'quant': 32320,
#    'amonut': 863,
#    'marketSum': 3336},
#   {'itemcode': '479080',
#    'etfTabCode': 6,
#    'itemname': '1Q 머니마켓액티브',
#    'nowVal': 50245,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.02,
#    'nav': 50242.0,
#    'threeMonthEarnRate': None,
#    'quant': 62280,
#    'amonut': 3129,
#    'marketSum': 3316},
#   {'itemcode': '394660',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#    'nowVal': 10920,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -0.32,
#    'nav': 10970.0,
#    'threeMonthEarnRate': 7.4546,
#    'quant': 41834,
#    'amonut': 457,
#    'marketSum': 3280},
#   {'itemcode': '466940',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 은행고배당플러스TOP10',
#    'nowVal': 13150,
#    'risefall': '2',
#    'changeVal': 335,
#    'changeRate': 2.61,
#    'nav': 13158.0,
#    'threeMonthEarnRate': 9.9339,
#    'quant': 311853,
#    'amonut': 4073,
#    'marketSum': 3189},
#   {'itemcode': '302190',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 중장기국채',
#    'nowVal': 49980,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.04,
#    'nav': 49987.0,
#    'threeMonthEarnRate': -0.09,
#    'quant': 2990,
#    'amonut': 149,
#    'marketSum': 3189},
#   {'itemcode': '467940',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 25-11 회사채(A+이상)액티브',
#    'nowVal': 10430,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.05,
#    'nav': 10425.0,
#    'threeMonthEarnRate': 1.0664,
#    'quant': 3793,
#    'amonut': 39,
#    'marketSum': 3180},
#   {'itemcode': '304660',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 미국30년국채울트라선물(H)',
#    'nowVal': 7775,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.19,
#    'nav': 7766.0,
#    'threeMonthEarnRate': -4.3747,
#    'quant': 728582,
#    'amonut': 5663,
#    'marketSum': 3172},
#   {'itemcode': '453870',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 인도니프티50',
#    'nowVal': 12375,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.36,
#    'nav': 12371.0,
#    'threeMonthEarnRate': 3.5177,
#    'quant': 332018,
#    'amonut': 4102,
#    'marketSum': 3168},
#   {'itemcode': '476550',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 미국30년국채프리미엄액티브(H)',
#    'nowVal': 9445,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.11,
#    'nav': 9448.0,
#    'threeMonthEarnRate': None,
#    'quant': 1091068,
#    'amonut': 10309,
#    'marketSum': 3140},
#   {'itemcode': '453810',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 인도Nifty50',
#    'nowVal': 12635,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.28,
#    'nav': 12652.0,
#    'threeMonthEarnRate': 3.4397,
#    'quant': 397801,
#    'amonut': 5022,
#    'marketSum': 3140},
#   {'itemcode': '394670',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#    'nowVal': 6925,
#    'risefall': '5',
#    'changeVal': -50,
#    'changeRate': -0.72,
#    'nav': 6942.0,
#    'threeMonthEarnRate': 14.6261,
#    'quant': 73436,
#    'amonut': 510,
#    'marketSum': 3138},
#   {'itemcode': '477080',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR CD금리액티브(합성)',
#    'nowVal': 100455,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.01,
#    'nav': 100427.0,
#    'threeMonthEarnRate': None,
#    'quant': 2048,
#    'amonut': 205,
#    'marketSum': 3114},
#   {'itemcode': '402970',
#    'etfTabCode': 4,
#    'itemname': 'ACE 미국배당다우존스',
#    'nowVal': 11535,
#    'risefall': '2',
#    'changeVal': 40,
#    'changeRate': 0.35,
#    'nav': 11501.0,
#    'threeMonthEarnRate': 4.9867,
#    'quant': 170844,
#    'amonut': 1969,
#    'marketSum': 3091},
#   {'itemcode': '388420',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 비메모리반도체액티브',
#    'nowVal': 14340,
#    'risefall': '2',
#    'changeVal': 60,
#    'changeRate': 0.42,
#    'nav': 14357.0,
#    'threeMonthEarnRate': 27.4203,
#    'quant': 357500,
#    'amonut': 5101,
#    'marketSum': 2920},
#   {'itemcode': '161510',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG 고배당주',
#    'nowVal': 13780,
#    'risefall': '2',
#    'changeVal': 165,
#    'changeRate': 1.21,
#    'nav': 13799.0,
#    'threeMonthEarnRate': 3.8441,
#    'quant': 173608,
#    'amonut': 2383,
#    'marketSum': 2861},
#   {'itemcode': '439860',
#    'etfTabCode': 6,
#    'itemname': 'KODEX ESG종합채권(A-이상)액티브',
#    'nowVal': 109110,
#    'risefall': '2',
#    'changeVal': 175,
#    'changeRate': 0.16,
#    'nav': 109091.0,
#    'threeMonthEarnRate': 0.9732,
#    'quant': 10,
#    'amonut': 1,
#    'marketSum': 2793},
#   {'itemcode': '439870',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 국고채30년액티브',
#    'nowVal': 104735,
#    'risefall': '2',
#    'changeVal': 90,
#    'changeRate': 0.09,
#    'nav': 104803.0,
#    'threeMonthEarnRate': -0.787,
#    'quant': 4683,
#    'amonut': 490,
#    'marketSum': 2778},
#   {'itemcode': '143860',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 헬스케어',
#    'nowVal': 34085,
#    'risefall': '5',
#    'changeVal': -15,
#    'changeRate': -0.04,
#    'nav': 34218.0,
#    'threeMonthEarnRate': 13.3982,
#    'quant': 48380,
#    'amonut': 1642,
#    'marketSum': 2768},
#   {'itemcode': '472870',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 미국30년국채엔화노출(합성 H)',
#    'nowVal': 8620,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.12,
#    'nav': 8613.0,
#    'threeMonthEarnRate': -7.6478,
#    'quant': 439563,
#    'amonut': 3793,
#    'marketSum': 2728},
#   {'itemcode': '456610',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 미국달러SOFR금리액티브(합성)',
#    'nowVal': 53610,
#    'risefall': '2',
#    'changeVal': 245,
#    'changeRate': 0.46,
#    'nav': 53562.0,
#    'threeMonthEarnRate': 3.4706,
#    'quant': 7627,
#    'amonut': 408,
#    'marketSum': 2704},
#   {'itemcode': '474220',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국테크TOP10+10%프리미엄',
#    'nowVal': 11365,
#    'risefall': '2',
#    'changeVal': 50,
#    'changeRate': 0.44,
#    'nav': 11338.0,
#    'threeMonthEarnRate': 10.1538,
#    'quant': 536213,
#    'amonut': 6093,
#    'marketSum': 2625},
#   {'itemcode': '091230',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 반도체',
#    'nowVal': 43565,
#    'risefall': '2',
#    'changeVal': 245,
#    'changeRate': 0.57,
#    'nav': 43533.0,
#    'threeMonthEarnRate': 21.6238,
#    'quant': 114769,
#    'amonut': 4983,
#    'marketSum': 2605},
#   {'itemcode': '245710',
#    'etfTabCode': 4,
#    'itemname': 'ACE 베트남VN30(합성)',
#    'nowVal': 19465,
#    'risefall': '2',
#    'changeVal': 85,
#    'changeRate': 0.44,
#    'nav': 19648.0,
#    'threeMonthEarnRate': 4.0257,
#    'quant': 90212,
#    'amonut': 1757,
#    'marketSum': 2589},
#   {'itemcode': '457480',
#    'etfTabCode': 4,
#    'itemname': 'ACE 테슬라밸류체인액티브',
#    'nowVal': 10130,
#    'risefall': '5',
#    'changeVal': -315,
#    'changeRate': -3.02,
#    'nav': 10109.0,
#    'threeMonthEarnRate': 8.1822,
#    'quant': 869683,
#    'amonut': 8830,
#    'marketSum': 2558},
#   {'itemcode': '471990',
#    'etfTabCode': 2,
#    'itemname': 'KODEX AI반도체핵심장비',
#    'nowVal': 14040,
#    'risefall': '2',
#    'changeVal': 195,
#    'changeRate': 1.41,
#    'nav': 14077.0,
#    'threeMonthEarnRate': 41.5499,
#    'quant': 1596619,
#    'amonut': 22267,
#    'marketSum': 2541},
#   {'itemcode': '290130',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR ESG사회책임투자',
#    'nowVal': 12585,
#    'risefall': '2',
#    'changeVal': 140,
#    'changeRate': 1.12,
#    'nav': 12625.0,
#    'threeMonthEarnRate': 6.1588,
#    'quant': 10376,
#    'amonut': 130,
#    'marketSum': 2448},
#   {'itemcode': '241180',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 일본니케이225',
#    'nowVal': 20400,
#    'risefall': '5',
#    'changeVal': -270,
#    'changeRate': -1.31,
#    'nav': 20336.0,
#    'threeMonthEarnRate': 6.2178,
#    'quant': 35311,
#    'amonut': 722,
#    'marketSum': 2432},
#   {'itemcode': '448880',
#    'etfTabCode': 6,
#    'itemname': 'ACE 24-12 회사채(AA-이상)액티브',
#    'nowVal': 104210,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.0,
#    'nav': 104210.0,
#    'threeMonthEarnRate': 0.964,
#    'quant': 3427,
#    'amonut': 357,
#    'marketSum': 2366},
#   {'itemcode': '451000',
#    'etfTabCode': 6,
#    'itemname': 'ARIRANG 종합채권(AA-이상)액티브',
#    'nowVal': 107015,
#    'risefall': '5',
#    'changeVal': -15,
#    'changeRate': -0.01,
#    'nav': 106963.0,
#    'threeMonthEarnRate': 0.6015,
#    'quant': 16,
#    'amonut': 1,
#    'marketSum': 2359},
#   {'itemcode': '367770',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR Fn수소경제테마',
#    'nowVal': 9290,
#    'risefall': '2',
#    'changeVal': 55,
#    'changeRate': 0.6,
#    'nav': 9323.0,
#    'threeMonthEarnRate': 3.7523,
#    'quant': 23928,
#    'amonut': 221,
#    'marketSum': 2336},
#   {'itemcode': '451600',
#    'etfTabCode': 6,
#    'itemname': 'ARIRANG 국고채30년액티브',
#    'nowVal': 100625,
#    'risefall': '2',
#    'changeVal': 80,
#    'changeRate': 0.08,
#    'nav': 100594.0,
#    'threeMonthEarnRate': -0.6669,
#    'quant': 124,
#    'amonut': 12,
#    'marketSum': 2250},
#   {'itemcode': '449180',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국S&P500(H)',
#    'nowVal': 12215,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.08,
#    'nav': 12216.0,
#    'threeMonthEarnRate': 4.3519,
#    'quant': 70704,
#    'amonut': 863,
#    'marketSum': 2241},
#   {'itemcode': '465580',
#    'etfTabCode': 4,
#    'itemname': 'ACE 미국빅테크TOP7 Plus',
#    'nowVal': 13310,
#    'risefall': '2',
#    'changeVal': 50,
#    'changeRate': 0.38,
#    'nav': 13315.0,
#    'threeMonthEarnRate': 12.1353,
#    'quant': 219390,
#    'amonut': 2923,
#    'marketSum': 2229},
#   {'itemcode': '361580',
#    'etfTabCode': 1,
#    'itemname': 'KBSTAR 200TR',
#    'nowVal': 20510,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.22,
#    'nav': 20564.0,
#    'threeMonthEarnRate': 6.5607,
#    'quant': 29892,
#    'amonut': 611,
#    'marketSum': 2164},
#   {'itemcode': '456600',
#    'etfTabCode': 4,
#    'itemname': 'TIMEFOLIO 글로벌AI인공지능액티브',
#    'nowVal': 18795,
#    'risefall': '5',
#    'changeVal': -65,
#    'changeRate': -0.34,
#    'nav': 18805.0,
#    'threeMonthEarnRate': 18.3929,
#    'quant': 171025,
#    'amonut': 3219,
#    'marketSum': 2161},
#   {'itemcode': '448290',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국S&P500TR(H)',
#    'nowVal': 12570,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.16,
#    'nav': 12566.0,
#    'threeMonthEarnRate': 4.3659,
#    'quant': 47027,
#    'amonut': 591,
#    'marketSum': 2156},
#   {'itemcode': '422420',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 2차전지액티브',
#    'nowVal': 9965,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.3,
#    'nav': 9993.0,
#    'threeMonthEarnRate': -0.6997,
#    'quant': 24062,
#    'amonut': 238,
#    'marketSum': 2154},
#   {'itemcode': '200250',
#    'etfTabCode': 4,
#    'itemname': 'KOSEF 인도Nifty50(합성)',
#    'nowVal': 23290,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.09,
#    'nav': 23174.0,
#    'threeMonthEarnRate': 3.5833,
#    'quant': 90877,
#    'amonut': 2110,
#    'marketSum': 2131},
#   {'itemcode': '295040',
#    'etfTabCode': 1,
#    'itemname': 'SOL 200TR',
#    'nowVal': 13565,
#    'risefall': '2',
#    'changeVal': 55,
#    'changeRate': 0.41,
#    'nav': 13587.0,
#    'threeMonthEarnRate': 6.336,
#    'quant': 149991,
#    'amonut': 2030,
#    'marketSum': 2096},
#   {'itemcode': '192090',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 차이나CSI300',
#    'nowVal': 8990,
#    'risefall': '5',
#    'changeVal': -70,
#    'changeRate': -0.77,
#    'nav': 8979.0,
#    'threeMonthEarnRate': 12.4767,
#    'quant': 84793,
#    'amonut': 763,
#    'marketSum': 2095},
#   {'itemcode': '423920',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#    'nowVal': 22555,
#    'risefall': '2',
#    'changeVal': 60,
#    'changeRate': 0.27,
#    'nav': 22389.0,
#    'threeMonthEarnRate': 23.9393,
#    'quant': 199817,
#    'amonut': 4491,
#    'marketSum': 2071},
#   {'itemcode': '411060',
#    'etfTabCode': 5,
#    'itemname': 'ACE KRX금현물',
#    'nowVal': 14610,
#    'risefall': '2',
#    'changeVal': 60,
#    'changeRate': 0.41,
#    'nav': 14544.0,
#    'threeMonthEarnRate': 17.1026,
#    'quant': 116567,
#    'amonut': 1699,
#    'marketSum': 2060},
#   {'itemcode': '455860',
#    'etfTabCode': 2,
#    'itemname': 'SOL 2차전지소부장Fn',
#    'nowVal': 6820,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.15,
#    'nav': 6826.0,
#    'threeMonthEarnRate': -5.9393,
#    'quant': 127028,
#    'amonut': 859,
#    'marketSum': 2022},
#   {'itemcode': '372330',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 차이나항셍테크',
#    'nowVal': 5860,
#    'risefall': '5',
#    'changeVal': -30,
#    'changeRate': -0.51,
#    'nav': 5835.0,
#    'threeMonthEarnRate': 26.6666,
#    'quant': 1103304,
#    'amonut': 6499,
#    'marketSum': 2007},
#   {'itemcode': '473290',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 26-12 회사채(AA-이상)액티브',
#    'nowVal': 10240,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.1,
#    'nav': 10237.0,
#    'threeMonthEarnRate': 1.1369,
#    'quant': 27170,
#    'amonut': 278,
#    'marketSum': 1958},
#   {'itemcode': '464540',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 25-03 회사채(AA-이상)액티브',
#    'nowVal': 50915,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.03,
#    'nav': 50889.0,
#    'threeMonthEarnRate': 0.9179,
#    'quant': 22707,
#    'amonut': 1156,
#    'marketSum': 1911},
#   {'itemcode': '332940',
#    'etfTabCode': 1,
#    'itemname': 'HANARO MSCI Korea TR',
#    'nowVal': 16000,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 16047.0,
#    'threeMonthEarnRate': 6.8447,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 1904},
#   {'itemcode': '143850',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국S&P500선물(H)',
#    'nowVal': 57515,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.05,
#    'nav': 57525.0,
#    'threeMonthEarnRate': 3.6699,
#    'quant': 17367,
#    'amonut': 998,
#    'marketSum': 1884},
#   {'itemcode': '471230',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 국고채10년액티브',
#    'nowVal': 105160,
#    'risefall': '2',
#    'changeVal': 115,
#    'changeRate': 0.11,
#    'nav': 105173.0,
#    'threeMonthEarnRate': -0.4125,
#    'quant': 3584,
#    'amonut': 376,
#    'marketSum': 1879},
#   {'itemcode': '328370',
#    'etfTabCode': 1,
#    'itemname': 'ARIRANG 코스피TR',
#    'nowVal': 14790,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.1,
#    'nav': 14807.0,
#    'threeMonthEarnRate': 5.7623,
#    'quant': 26,
#    'amonut': 0,
#    'marketSum': 1878},
#   {'itemcode': '409820',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#    'nowVal': 9485,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.21,
#    'nav': 9518.0,
#    'threeMonthEarnRate': 3.4426,
#    'quant': 162907,
#    'amonut': 1547,
#    'marketSum': 1873},
#   {'itemcode': '272560',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 단기국공채액티브',
#    'nowVal': 108865,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.03,
#    'nav': 108835.0,
#    'threeMonthEarnRate': 0.7451,
#    'quant': 2580,
#    'amonut': 280,
#    'marketSum': 1847},
#   {'itemcode': '395270',
#    'etfTabCode': 2,
#    'itemname': 'HANARO Fn K-반도체',
#    'nowVal': 11985,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.04,
#    'nav': 11998.0,
#    'threeMonthEarnRate': 21.7603,
#    'quant': 136918,
#    'amonut': 1633,
#    'marketSum': 1834},
#   {'itemcode': '462330',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 2차전지산업레버리지',
#    'nowVal': 3830,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.13,
#    'nav': 3851.0,
#    'threeMonthEarnRate': -4.2554,
#    'quant': 977974,
#    'amonut': 3708,
#    'marketSum': 1823},
#   {'itemcode': '469820',
#    'etfTabCode': 6,
#    'itemname': 'SOL 24-12 회사채(AA-이상)액티브',
#    'nowVal': 51340,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.02,
#    'nav': 51343.0,
#    'threeMonthEarnRate': 0.9538,
#    'quant': 2285,
#    'amonut': 117,
#    'marketSum': 1801},
#   {'itemcode': '449190',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국나스닥100(H)',
#    'nowVal': 14395,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.03,
#    'nav': 14402.0,
#    'threeMonthEarnRate': 2.5275,
#    'quant': 579311,
#    'amonut': 8347,
#    'marketSum': 1771},
#   {'itemcode': '463290',
#    'etfTabCode': 6,
#    'itemname': '1Q 단기금융채액티브',
#    'nowVal': 103425,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.01,
#    'nav': 103420.0,
#    'threeMonthEarnRate': 0.9123,
#    'quant': 2985,
#    'amonut': 308,
#    'marketSum': 1717},
#   {'itemcode': '445290',
#    'etfTabCode': 2,
#    'itemname': 'KODEX K-로봇액티브',
#    'nowVal': 14280,
#    'risefall': '5',
#    'changeVal': -75,
#    'changeRate': -0.52,
#    'nav': 14302.0,
#    'threeMonthEarnRate': 1.0701,
#    'quant': 57476,
#    'amonut': 820,
#    'marketSum': 1692},
#   {'itemcode': '326240',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR IT플러스',
#    'nowVal': 18955,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -0.18,
#    'nav': 19013.0,
#    'threeMonthEarnRate': 8.3224,
#    'quant': 19139,
#    'amonut': 362,
#    'marketSum': 1668},
#   {'itemcode': '477050',
#    'etfTabCode': 6,
#    'itemname': 'ARIRANG 머니마켓액티브',
#    'nowVal': 50265,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.03,
#    'nav': 50253.0,
#    'threeMonthEarnRate': None,
#    'quant': 31622,
#    'amonut': 1589,
#    'marketSum': 1655},
#   {'itemcode': '464230',
#    'etfTabCode': 6,
#    'itemname': '히어로즈 24-09 회사채(AA-이상)액티브',
#    'nowVal': 51250,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.01,
#    'nav': 51254.0,
#    'threeMonthEarnRate': 0.8541,
#    'quant': 12326,
#    'amonut': 631,
#    'marketSum': 1650},
#   {'itemcode': '364960',
#    'etfTabCode': 2,
#    'itemname': 'TIGER BBIG',
#    'nowVal': 6255,
#    'risefall': '2',
#    'changeVal': 25,
#    'changeRate': 0.4,
#    'nav': 6268.0,
#    'threeMonthEarnRate': 0.9724,
#    'quant': 103394,
#    'amonut': 649,
#    'marketSum': 1626},
#   {'itemcode': '466920',
#    'etfTabCode': 2,
#    'itemname': 'SOL 조선TOP3플러스',
#    'nowVal': 10835,
#    'risefall': '2',
#    'changeVal': 15,
#    'changeRate': 0.14,
#    'nav': 10827.0,
#    'threeMonthEarnRate': 22.8149,
#    'quant': 2620806,
#    'amonut': 28339,
#    'marketSum': 1614},
#   {'itemcode': '452360',
#    'etfTabCode': 4,
#    'itemname': 'SOL 미국배당다우존스(H)',
#    'nowVal': 10810,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.05,
#    'nav': 10802.0,
#    'threeMonthEarnRate': 1.9243,
#    'quant': 72440,
#    'amonut': 782,
#    'marketSum': 1611},
#   {'itemcode': '451060',
#    'etfTabCode': 1,
#    'itemname': '1Q K200액티브',
#    'nowVal': 11880,
#    'risefall': '2',
#    'changeVal': 40,
#    'changeRate': 0.34,
#    'nav': 11912.0,
#    'threeMonthEarnRate': 6.2359,
#    'quant': 368740,
#    'amonut': 4373,
#    'marketSum': 1586},
#   {'itemcode': '329650',
#    'etfTabCode': 7,
#    'itemname': 'KODEX TRF3070',
#    'nowVal': 12415,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 12422.0,
#    'threeMonthEarnRate': 3.4583,
#    'quant': 33476,
#    'amonut': 415,
#    'marketSum': 1564},
#   {'itemcode': '363570',
#    'etfTabCode': 6,
#    'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#    'nowVal': 92270,
#    'risefall': '2',
#    'changeVal': 105,
#    'changeRate': 0.11,
#    'nav': 92310.0,
#    'threeMonthEarnRate': 0.0162,
#    'quant': 21,
#    'amonut': 1,
#    'marketSum': 1560},
#   {'itemcode': '132030',
#    'etfTabCode': 5,
#    'itemname': 'KODEX 골드선물(H)',
#    'nowVal': 14435,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -0.24,
#    'nav': 14436.0,
#    'threeMonthEarnRate': 13.1352,
#    'quant': 96398,
#    'amonut': 1392,
#    'marketSum': 1559},
#   {'itemcode': '438330',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 투자등급회사채액티브',
#    'nowVal': 109750,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.03,
#    'nav': 109775.0,
#    'threeMonthEarnRate': 1.1337,
#    'quant': 3043,
#    'amonut': 333,
#    'marketSum': 1541},
#   {'itemcode': '473330',
#    'etfTabCode': 6,
#    'itemname': 'SOL 미국30년국채커버드콜(합성)',
#    'nowVal': 9800,
#    'risefall': '2',
#    'changeVal': 55,
#    'changeRate': 0.56,
#    'nav': 9786.0,
#    'threeMonthEarnRate': -0.8042,
#    'quant': 341355,
#    'amonut': 3343,
#    'marketSum': 1524},
#   {'itemcode': '325020',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 배당가치',
#    'nowVal': 14315,
#    'risefall': '2',
#    'changeVal': 125,
#    'changeRate': 0.88,
#    'nav': 14331.0,
#    'threeMonthEarnRate': 3.11,
#    'quant': 8497,
#    'amonut': 121,
#    'marketSum': 1503},
#   {'itemcode': '261260',
#    'etfTabCode': 7,
#    'itemname': 'KODEX 미국달러선물인버스2X',
#    'nowVal': 6030,
#    'risefall': '5',
#    'changeVal': -40,
#    'changeRate': -0.66,
#    'nav': 6045.0,
#    'threeMonthEarnRate': -5.5988,
#    'quant': 420187,
#    'amonut': 2532,
#    'marketSum': 1498},
#   {'itemcode': '461950',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 2차전지핵심소재10 Fn',
#    'nowVal': 7375,
#    'risefall': '5',
#    'changeVal': -10,
#    'changeRate': -0.14,
#    'nav': 7376.0,
#    'threeMonthEarnRate': -5.611,
#    'quant': 243698,
#    'amonut': 1780,
#    'marketSum': 1493},
#   {'itemcode': '451530',
#    'etfTabCode': 6,
#    'itemname': 'TIGER 국고채30년스트립액티브',
#    'nowVal': 49545,
#    'risefall': '2',
#    'changeVal': 140,
#    'changeRate': 0.28,
#    'nav': 49599.0,
#    'threeMonthEarnRate': -1.2888,
#    'quant': 28724,
#    'amonut': 1425,
#    'marketSum': 1474},
#   {'itemcode': '471760',
#    'etfTabCode': 2,
#    'itemname': 'TIGER AI반도체핵심공정',
#    'nowVal': 13340,
#    'risefall': '2',
#    'changeVal': 135,
#    'changeRate': 1.02,
#    'nav': 13359.0,
#    'threeMonthEarnRate': 37.8392,
#    'quant': 851391,
#    'amonut': 11242,
#    'marketSum': 1421},
#   {'itemcode': '244580',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 바이오',
#    'nowVal': 8120,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.25,
#    'nav': 8160.0,
#    'threeMonthEarnRate': 11.6009,
#    'quant': 151198,
#    'amonut': 1222,
#    'marketSum': 1416},
#   {'itemcode': '401470',
#    'etfTabCode': 2,
#    'itemname': 'KODEX K-메타버스액티브',
#    'nowVal': 7290,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.07,
#    'nav': 7319.0,
#    'threeMonthEarnRate': 3.9914,
#    'quant': 46981,
#    'amonut': 342,
#    'marketSum': 1411},
#   {'itemcode': '476070',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 글로벌비만치료제TOP2 Plus',
#    'nowVal': 11945,
#    'risefall': '2',
#    'changeVal': 140,
#    'changeRate': 1.19,
#    'nav': 11962.0,
#    'threeMonthEarnRate': None,
#    'quant': 286361,
#    'amonut': 3418,
#    'marketSum': 1410},
#   {'itemcode': '219480',
#    'etfTabCode': 4,
#    'itemname': 'KODEX 미국S&P500선물(H)',
#    'nowVal': 23820,
#    'risefall': '2',
#    'changeVal': 25,
#    'changeRate': 0.11,
#    'nav': 23824.0,
#    'threeMonthEarnRate': 3.9082,
#    'quant': 7108,
#    'amonut': 169,
#    'marketSum': 1405},
#   {'itemcode': '292560',
#    'etfTabCode': 7,
#    'itemname': 'TIGER 일본엔선물',
#    'nowVal': 8410,
#    'risefall': '5',
#    'changeVal': -15,
#    'changeRate': -0.18,
#    'nav': 8395.0,
#    'threeMonthEarnRate': -1.9779,
#    'quant': 251463,
#    'amonut': 2116,
#    'marketSum': 1396},
#   {'itemcode': '190620',
#    'etfTabCode': 6,
#    'itemname': 'ACE 단기통안채',
#    'nowVal': 101525,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.01,
#    'nav': 101522.0,
#    'threeMonthEarnRate': 0.7793,
#    'quant': 5167,
#    'amonut': 524,
#    'marketSum': 1384},
#   {'itemcode': '475080',
#    'etfTabCode': 7,
#    'itemname': 'KODEX 테슬라인컴프리미엄채권혼합액티브',
#    'nowVal': 9445,
#    'risefall': '5',
#    'changeVal': -15,
#    'changeRate': -0.16,
#    'nav': 9434.0,
#    'threeMonthEarnRate': 0.8098,
#    'quant': 399399,
#    'amonut': 3771,
#    'marketSum': 1379},
#   {'itemcode': '462900',
#    'etfTabCode': 2,
#    'itemname': 'KoAct 바이오헬스케어액티브',
#    'nowVal': 11430,
#    'risefall': '5',
#    'changeVal': -70,
#    'changeRate': -0.61,
#    'nav': 11424.0,
#    'threeMonthEarnRate': 22.549,
#    'quant': 1098821,
#    'amonut': 12510,
#    'marketSum': 1360},
#   {'itemcode': '448300',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 미국나스닥100TR(H)',
#    'nowVal': 14770,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 14774.0,
#    'threeMonthEarnRate': 2.5338,
#    'quant': 180329,
#    'amonut': 2663,
#    'marketSum': 1359},
#   {'itemcode': '275980',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#    'nowVal': 16325,
#    'risefall': '5',
#    'changeVal': -55,
#    'changeRate': -0.34,
#    'nav': 16428.0,
#    'threeMonthEarnRate': -0.4861,
#    'quant': 7506,
#    'amonut': 122,
#    'marketSum': 1306},
#   {'itemcode': '461270',
#    'etfTabCode': 6,
#    'itemname': 'ACE 26-06 회사채(AA-이상)액티브',
#    'nowVal': 10540,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.05,
#    'nav': 10537.0,
#    'threeMonthEarnRate': 1.298,
#    'quant': 94662,
#    'amonut': 997,
#    'marketSum': 1297},
#   {'itemcode': '449450',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG K방산Fn',
#    'nowVal': 15905,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.06,
#    'nav': 15928.0,
#    'threeMonthEarnRate': 32.4252,
#    'quant': 217229,
#    'amonut': 3433,
#    'marketSum': 1288},
#   {'itemcode': '412770',
#    'etfTabCode': 4,
#    'itemname': 'TIGER 글로벌메타버스액티브',
#    'nowVal': 9360,
#    'risefall': '2',
#    'changeVal': 115,
#    'changeRate': 1.24,
#    'nav': 9392.0,
#    'threeMonthEarnRate': 5.1763,
#    'quant': 20359,
#    'amonut': 190,
#    'marketSum': 1275},
#   {'itemcode': '228790',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 화장품',
#    'nowVal': 2815,
# ...
#    'threeMonthEarnRate': 10.5394,
#    'quant': 204,
#    'amonut': 2,
#    'marketSum': 47},
#   {'itemcode': '227550',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200 산업재',
#    'nowVal': 6655,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.68,
#    'nav': 6652.0,
#    'threeMonthEarnRate': 7.1486,
#    'quant': 2368,
#    'amonut': 15,
#    'marketSum': 47},
#   {'itemcode': '140570',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 수출주',
#    'nowVal': 11615,
#    'risefall': '2',
#    'changeVal': 130,
#    'changeRate': 1.13,
#    'nav': 11639.0,
#    'threeMonthEarnRate': 7.0463,
#    'quant': 400,
#    'amonut': 4,
#    'marketSum': 46},
#   {'itemcode': '416090',
#    'etfTabCode': 4,
#    'itemname': 'ACE 중국과창판STAR50',
#    'nowVal': 5645,
#    'risefall': '5',
#    'changeVal': -75,
#    'changeRate': -1.31,
#    'nav': 5696.0,
#    'threeMonthEarnRate': 8.5388,
#    'quant': 1452,
#    'amonut': 8,
#    'marketSum': 45},
#   {'itemcode': '413220',
#    'etfTabCode': 4,
#    'itemname': 'SOL 차이나태양광CSI(합성)',
#    'nowVal': 4460,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.11,
#    'nav': 4462.0,
#    'threeMonthEarnRate': 4.2007,
#    'quant': 2394,
#    'amonut': 10,
#    'marketSum': 45},
#   {'itemcode': '395760',
#    'etfTabCode': 2,
#    'itemname': 'ARIRANG ESG성장주액티브',
#    'nowVal': 8900,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.39,
#    'nav': 8913.0,
#    'threeMonthEarnRate': 8.7463,
#    'quant': 9674,
#    'amonut': 85,
#    'marketSum': 45},
#   {'itemcode': '281990',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 중소형고배당',
#    'nowVal': 11095,
#    'risefall': '2',
#    'changeVal': 70,
#    'changeRate': 0.63,
#    'nav': 11118.0,
#    'threeMonthEarnRate': -1.7993,
#    'quant': 893,
#    'amonut': 9,
#    'marketSum': 44},
#   {'itemcode': '284980',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200금융',
#    'nowVal': 10565,
#    'risefall': '2',
#    'changeVal': 275,
#    'changeRate': 2.67,
#    'nav': 10582.0,
#    'threeMonthEarnRate': 7.0091,
#    'quant': 3925,
#    'amonut': 41,
#    'marketSum': 44},
#   {'itemcode': '244660',
#    'etfTabCode': 2,
#    'itemname': 'KODEX 퀄리티Plus',
#    'nowVal': 8765,
#    'risefall': '2',
#    'changeVal': 60,
#    'changeRate': 0.69,
#    'nav': 8771.0,
#    'threeMonthEarnRate': 0.3111,
#    'quant': 8,
#    'amonut': 0,
#    'marketSum': 44},
#   {'itemcode': '285000',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200IT',
#    'nowVal': 15470,
#    'risefall': '2',
#    'changeVal': 55,
#    'changeRate': 0.36,
#    'nav': 15473.0,
#    'threeMonthEarnRate': 10.8115,
#    'quant': 653,
#    'amonut': 10,
#    'marketSum': 43},
#   {'itemcode': '238670',
#    'etfTabCode': 7,
#    'itemname': 'ARIRANG 스마트베타Quality채권혼합',
#    'nowVal': 10755,
#    'risefall': '2',
#    'changeVal': 30,
#    'changeRate': 0.28,
#    'nav': 10758.0,
#    'threeMonthEarnRate': -0.2233,
#    'quant': 430,
#    'amonut': 4,
#    'marketSum': 43},
#   {'itemcode': '465620',
#    'etfTabCode': 4,
#    'itemname': 'ACE 미국빅테크TOP7 Plus인버스(합성)',
#    'nowVal': 14305,
#    'risefall': '5',
#    'changeVal': -60,
#    'changeRate': -0.42,
#    'nav': 14324.0,
#    'threeMonthEarnRate': -12.6748,
#    'quant': 1995,
#    'amonut': 28,
#    'marketSum': 43},
#   {'itemcode': '306520',
#    'etfTabCode': 3,
#    'itemname': 'HANARO 200선물인버스',
#    'nowVal': 9530,
#    'risefall': '5',
#    'changeVal': -20,
#    'changeRate': -0.21,
#    'nav': 9512.0,
#    'threeMonthEarnRate': -5.1639,
#    'quant': 215,
#    'amonut': 2,
#    'marketSum': 43},
#   {'itemcode': '285010',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200중공업',
#    'nowVal': 13335,
#    'risefall': '2',
#    'changeVal': 160,
#    'changeRate': 1.21,
#    'nav': 13329.0,
#    'threeMonthEarnRate': 26.0886,
#    'quant': 2721,
#    'amonut': 36,
#    'marketSum': 43},
#   {'itemcode': '426330',
#    'etfTabCode': 4,
#    'itemname': 'KOSEF 미국ETF산업STOXX',
#    'nowVal': 12185,
#    'risefall': '2',
#    'changeVal': 185,
#    'changeRate': 1.54,
#    'nav': 12197.0,
#    'threeMonthEarnRate': 2.6957,
#    'quant': 170,
#    'amonut': 2,
#    'marketSum': 43},
#   {'itemcode': '291630',
#    'etfTabCode': 3,
#    'itemname': 'KOSEF 코스닥150선물레버리지',
#    'nowVal': 5815,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 5830.0,
#    'threeMonthEarnRate': 27.3822,
#    'quant': 39582,
#    'amonut': 227,
#    'marketSum': 42},
#   {'itemcode': '473380',
#    'etfTabCode': 2,
#    'itemname': 'HANARO K-메디테크',
#    'nowVal': 8365,
#    'risefall': '2',
#    'changeVal': 150,
#    'changeRate': 1.83,
#    'nav': 8401.0,
#    'threeMonthEarnRate': -1.3214,
#    'quant': 11,
#    'amonut': 0,
#    'marketSum': 42},
#   {'itemcode': '295820',
#    'etfTabCode': 1,
#    'itemname': 'ARIRANG 200동일가중',
#    'nowVal': 10385,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 10483.0,
#    'threeMonthEarnRate': 3.6944,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 42},
#   {'itemcode': '284990',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200에너지화학',
#    'nowVal': 8595,
#    'risefall': '2',
#    'changeVal': 105,
#    'changeRate': 1.24,
#    'nav': 8612.0,
#    'threeMonthEarnRate': -6.5802,
#    'quant': 1109,
#    'amonut': 9,
#    'marketSum': 41},
#   {'itemcode': '448510',
#    'etfTabCode': 4,
#    'itemname': 'HANARO 글로벌신재생에너지MSCI(합성)',
#    'nowVal': 7405,
#    'risefall': '2',
#    'changeVal': 65,
#    'changeRate': 0.89,
#    'nav': 7396.0,
#    'threeMonthEarnRate': 10.9599,
#    'quant': 1735,
#    'amonut': 12,
#    'marketSum': 41},
#   {'itemcode': '429870',
#    'etfTabCode': 7,
#    'itemname': '히어로즈 리츠이지스액티브',
#    'nowVal': 7370,
#    'risefall': '2',
#    'changeVal': 5,
#    'changeRate': 0.07,
#    'nav': 7456.0,
#    'threeMonthEarnRate': 5.8341,
#    'quant': 13997,
#    'amonut': 102,
#    'marketSum': 41},
#   {'itemcode': '295000',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 국채선물10년',
#    'nowVal': 51840,
#    'risefall': '2',
#    'changeVal': 80,
#    'changeRate': 0.15,
#    'nav': 51827.0,
#    'threeMonthEarnRate': -0.8714,
#    'quant': 143,
#    'amonut': 7,
#    'marketSum': 40},
#   {'itemcode': '445930',
#    'etfTabCode': 4,
#    'itemname': 'KOSEF 차이나A50커넥트레버리지MSCI(합성H)',
#    'nowVal': 8060,
#    'risefall': '5',
#    'changeVal': -190,
#    'changeRate': -2.3,
#    'nav': 8430.0,
#    'threeMonthEarnRate': 25.1896,
#    'quant': 702,
#    'amonut': 5,
#    'marketSum': 40},
#   {'itemcode': '256450',
#    'etfTabCode': 4,
#    'itemname': 'ARIRANG 심천차이넥스트(합성)',
#    'nowVal': 8055,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 7994.0,
#    'threeMonthEarnRate': 13.7711,
#    'quant': 10,
#    'amonut': 0,
#    'marketSum': 40},
#   {'itemcode': '427120',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR Fn플랫폼테마',
#    'nowVal': 6695,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.53,
#    'nav': 6708.0,
#    'threeMonthEarnRate': -5.3305,
#    'quant': 107,
#    'amonut': 0,
#    'marketSum': 40},
#   {'itemcode': '215620',
#    'etfTabCode': 2,
#    'itemname': 'HK S&P코리아로우볼',
#    'nowVal': 12745,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 12836.0,
#    'threeMonthEarnRate': -0.1489,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 38},
#   {'itemcode': '147970',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 모멘텀',
#    'nowVal': 27235,
#    'risefall': '2',
#    'changeVal': 200,
#    'changeRate': 0.74,
#    'nav': 27202.0,
#    'threeMonthEarnRate': 14.6376,
#    'quant': 946,
#    'amonut': 25,
#    'marketSum': 38},
#   {'itemcode': '407170',
#    'etfTabCode': 2,
#    'itemname': 'KCGI 스마트커머스액티브',
#    'nowVal': 7615,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.13,
#    'nav': 7620.0,
#    'threeMonthEarnRate': 9.3457,
#    'quant': 189,
#    'amonut': 1,
#    'marketSum': 38},
#   {'itemcode': '407300',
#    'etfTabCode': 2,
#    'itemname': 'HANARO Fn골프테마',
#    'nowVal': 5850,
#    'risefall': '2',
#    'changeVal': 20,
#    'changeRate': 0.34,
#    'nav': 5890.0,
#    'threeMonthEarnRate': -4.7386,
#    'quant': 23,
#    'amonut': 0,
#    'marketSum': 38},
#   {'itemcode': '139310',
#    'etfTabCode': 5,
#    'itemname': 'TIGER 금속선물(H)',
#    'nowVal': 6260,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.08,
#    'nav': 6325.0,
#    'threeMonthEarnRate': 15.5904,
#    'quant': 2134,
#    'amonut': 13,
#    'marketSum': 38},
#   {'itemcode': '243890',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200에너지화학레버리지',
#    'nowVal': 6765,
#    'risefall': '2',
#    'changeVal': 95,
#    'changeRate': 1.42,
#    'nav': 6834.0,
#    'threeMonthEarnRate': -14.4872,
#    'quant': 49835,
#    'amonut': 332,
#    'marketSum': 36},
#   {'itemcode': '469790',
#    'etfTabCode': 2,
#    'itemname': 'KOSEF K-테크TOP10',
#    'nowVal': 11715,
#    'risefall': '5',
#    'changeVal': -70,
#    'changeRate': -0.59,
#    'nav': 11710.0,
#    'threeMonthEarnRate': 8.5174,
#    'quant': 80,
#    'amonut': 0,
#    'marketSum': 35},
#   {'itemcode': '098560',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 방송통신',
#    'nowVal': 6885,
#    'risefall': '5',
#    'changeVal': -35,
#    'changeRate': -0.51,
#    'nav': 6881.0,
#    'threeMonthEarnRate': -5.3223,
#    'quant': 5940,
#    'amonut': 40,
#    'marketSum': 34},
#   {'itemcode': '220130',
#    'etfTabCode': 4,
#    'itemname': 'SOL 차이나강소기업CSI500(합성 H)',
#    'nowVal': 4270,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.12,
#    'nav': 4263.0,
#    'threeMonthEarnRate': 7.8184,
#    'quant': 103,
#    'amonut': 0,
#    'marketSum': 34},
#   {'itemcode': '227560',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200 생활소비재',
#    'nowVal': 8455,
#    'risefall': '5',
#    'changeVal': -15,
#    'changeRate': -0.18,
#    'nav': 8461.0,
#    'threeMonthEarnRate': 8.4645,
#    'quant': 1069,
#    'amonut': 9,
#    'marketSum': 34},
#   {'itemcode': '285020',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200철강소재',
#    'nowVal': 8715,
#    'risefall': '2',
#    'changeVal': 40,
#    'changeRate': 0.46,
#    'nav': 8753.0,
#    'threeMonthEarnRate': 0.4515,
#    'quant': 2673,
#    'amonut': 23,
#    'marketSum': 33},
#   {'itemcode': '472490',
#    'etfTabCode': 4,
#    'itemname': 'HANARO 미국애그테크',
#    'nowVal': 10970,
#    'risefall': '2',
#    'changeVal': 220,
#    'changeRate': 2.05,
#    'nav': 11027.0,
#    'threeMonthEarnRate': 8.7506,
#    'quant': 617,
#    'amonut': 6,
#    'marketSum': 33},
#   {'itemcode': '291620',
#    'etfTabCode': 3,
#    'itemname': 'KOSEF 코스닥150선물인버스',
#    'nowVal': 6150,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.08,
#    'nav': 6138.0,
#    'threeMonthEarnRate': -11.9457,
#    'quant': 6656,
#    'amonut': 41,
#    'marketSum': 33},
#   {'itemcode': '397420',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 국채선물5년추종',
#    'nowVal': 49370,
#    'risefall': '2',
#    'changeVal': 115,
#    'changeRate': 0.23,
#    'nav': 49330.0,
#    'threeMonthEarnRate': -0.4045,
#    'quant': 4,
#    'amonut': 0,
#    'marketSum': 33},
#   {'itemcode': '287300',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200건설',
#    'nowVal': 13380,
#    'risefall': '2',
#    'changeVal': 110,
#    'changeRate': 0.83,
#    'nav': 13372.0,
#    'threeMonthEarnRate': 1.0277,
#    'quant': 76,
#    'amonut': 1,
#    'marketSum': 32},
#   {'itemcode': '334700',
#    'etfTabCode': 5,
#    'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#    'nowVal': 6285,
#    'risefall': '2',
#    'changeVal': 35,
#    'changeRate': 0.56,
#    'nav': 6325.0,
#    'threeMonthEarnRate': -7.476,
#    'quant': 104,
#    'amonut': 0,
#    'marketSum': 31},
#   {'itemcode': '267500',
#    'etfTabCode': 6,
#    'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#    'nowVal': 10430,
#    'risefall': '5',
#    'changeVal': -205,
#    'changeRate': -1.93,
#    'nav': 10635.0,
#    'threeMonthEarnRate': 7.3158,
#    'quant': 48,
#    'amonut': 0,
#    'marketSum': 31},
#   {'itemcode': '306530',
#    'etfTabCode': 3,
#    'itemname': 'HANARO 코스닥150선물레버리지',
#    'nowVal': 11620,
#    'risefall': '5',
#    'changeVal': -110,
#    'changeRate': -0.94,
#    'nav': 11729.0,
#    'threeMonthEarnRate': 26.8793,
#    'quant': 666,
#    'amonut': 7,
#    'marketSum': 30},
#   {'itemcode': '275750',
#    'etfTabCode': 3,
#    'itemname': 'KBSTAR 코스닥150선물인버스',
#    'nowVal': 3515,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.14,
#    'nav': 3506.0,
#    'threeMonthEarnRate': -12.2195,
#    'quant': 2432,
#    'amonut': 8,
#    'marketSum': 30},
#   {'itemcode': '301410',
#    'etfTabCode': 3,
#    'itemname': 'ARIRANG 코스닥150선물인버스',
#    'nowVal': 5270,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.19,
#    'nav': 5293.0,
#    'threeMonthEarnRate': -11.8928,
#    'quant': 1620,
#    'amonut': 8,
#    'marketSum': 29},
#   {'itemcode': '315270',
#    'etfTabCode': 2,
#    'itemname': 'TIGER 200커뮤니케이션서비스',
#    'nowVal': 17390,
#    'risefall': '2',
#    'changeVal': 45,
#    'changeRate': 0.26,
#    'nav': 17392.0,
#    'threeMonthEarnRate': -2.3423,
#    'quant': 1256,
#    'amonut': 21,
#    'marketSum': 28},
#   {'itemcode': '253240',
#    'etfTabCode': 3,
#    'itemname': 'KOSEF 200선물인버스',
#    'nowVal': 5310,
#    'risefall': '5',
#    'changeVal': -20,
#    'changeRate': -0.38,
#    'nav': 5305.0,
#    'threeMonthEarnRate': -5.4126,
#    'quant': 1169,
#    'amonut': 6,
#    'marketSum': 28},
#   {'itemcode': '391590',
#    'etfTabCode': 4,
#    'itemname': 'ACE 미국스팩&IPO INDXX',
#    'nowVal': 5500,
#    'risefall': '2',
#    'changeVal': 10,
#    'changeRate': 0.18,
#    'nav': 5477.0,
#    'threeMonthEarnRate': 4.5714,
#    'quant': 185,
#    'amonut': 1,
#    'marketSum': 28},
#   {'itemcode': '473500',
#    'etfTabCode': 4,
#    'itemname': 'KOSEF 글로벌전력반도체',
#    'nowVal': 9010,
#    'risefall': '2',
#    'changeVal': 135,
#    'changeRate': 1.52,
#    'nav': 9133.0,
#    'threeMonthEarnRate': -3.0585,
#    'quant': 147199,
#    'amonut': 1319,
#    'marketSum': 27},
#   {'itemcode': '145670',
#    'etfTabCode': 3,
#    'itemname': 'ACE 인버스',
#    'nowVal': 5110,
#    'risefall': '5',
#    'changeVal': -20,
#    'changeRate': -0.39,
#    'nav': 5104.0,
#    'threeMonthEarnRate': -5.1757,
#    'quant': 2403,
#    'amonut': 12,
#    'marketSum': 26},
#   {'itemcode': '415920',
#    'etfTabCode': 5,
#    'itemname': 'ARIRANG 글로벌희토류전략자원기업MV',
#    'nowVal': 5090,
#    'risefall': '5',
#    'changeVal': -10,
#    'changeRate': -0.2,
#    'nav': 5196.0,
#    'threeMonthEarnRate': 0.691,
#    'quant': 1308,
#    'amonut': 6,
#    'marketSum': 25},
#   {'itemcode': '252720',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 모멘텀밸류',
#    'nowVal': 16610,
#    'risefall': '2',
#    'changeVal': 195,
#    'changeRate': 1.19,
#    'nav': 16617.0,
#    'threeMonthEarnRate': 6.2115,
#    'quant': 1163,
#    'amonut': 19,
#    'marketSum': 25},
#   {'itemcode': '299070',
#    'etfTabCode': 6,
#    'itemname': 'ACE 국채선물10년인버스',
#    'nowVal': 112955,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 112841.0,
#    'threeMonthEarnRate': 2.1847,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 23},
#   {'itemcode': '299080',
#    'etfTabCode': 6,
#    'itemname': 'ACE 국채선물3년인버스',
#    'nowVal': 110240,
#    'risefall': '3',
#    'changeVal': 0,
#    'changeRate': 0.0,
#    'nav': 110169.0,
#    'threeMonthEarnRate': 1.5756,
#    'quant': 0,
#    'amonut': 0,
#    'marketSum': 22},
#   {'itemcode': '287310',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200경기소비재',
#    'nowVal': 10660,
#    'risefall': '2',
#    'changeVal': 100,
#    'changeRate': 0.95,
#    'nav': 10659.0,
#    'threeMonthEarnRate': 0.1232,
#    'quant': 32,
#    'amonut': 0,
#    'marketSum': 21},
#   {'itemcode': '412560',
#    'etfTabCode': 2,
#    'itemname': 'TIGER BBIG레버리지',
#    'nowVal': 2210,
#    'risefall': '2',
#    'changeVal': 25,
#    'changeRate': 1.14,
#    'nav': 2226.0,
#    'threeMonthEarnRate': -0.9071,
#    'quant': 4169,
#    'amonut': 9,
#    'marketSum': 19},
#   {'itemcode': '252730',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 모멘텀로우볼',
#    'nowVal': 16285,
#    'risefall': '2',
#    'changeVal': 75,
#    'changeRate': 0.46,
#    'nav': 16300.0,
#    'threeMonthEarnRate': 6.8204,
#    'quant': 12,
#    'amonut': 0,
#    'marketSum': 16},
#   {'itemcode': '287330',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200생활소비재',
#    'nowVal': 6415,
#    'risefall': '5',
#    'changeVal': -5,
#    'changeRate': -0.08,
#    'nav': 6415.0,
#    'threeMonthEarnRate': 8.2995,
#    'quant': 2140,
#    'amonut': 13,
#    'marketSum': 14},
#   {'itemcode': '315480',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200커뮤니케이션서비스',
#    'nowVal': 10965,
#    'risefall': '2',
#    'changeVal': 25,
#    'changeRate': 0.23,
#    'nav': 10969.0,
#    'threeMonthEarnRate': -1.9011,
#    'quant': 119,
#    'amonut': 1,
#    'marketSum': 13},
#   {'itemcode': '287320',
#    'etfTabCode': 2,
#    'itemname': 'KBSTAR 200산업재',
#    'nowVal': 12495,
#    'risefall': '2',
#    'changeVal': 125,
#    'changeRate': 1.01,
#    'nav': 12504.0,
#    'threeMonthEarnRate': 8.0443,
#    'quant': 149,
#    'amonut': 1,
#    'marketSum': 10}]}

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져오기
etfItemList = etf_json["result"]['etfItemList']
len(etfItemList)
# Out:
# 856

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만들기
df = pd.DataFrame(etfItemList)
df.shape
# Out:
# (856, 12)

# %% [markdown]
# ### 데이터 확인

# %%
#상단 데이터의 일부 미리보기
df.head()
# Out:
#   itemcode  etfTabCode             itemname   nowVal risefall  changeVal  \
# 0   459580           6    KODEX CD금리액티브(합성)  1035155        2        100
# 1   357870           6  TIGER CD금리투자KIS(합성)    54265        2          5
# 2   069500           1            KODEX 200    37460        2        130
# 3   423160           6  KODEX KOFR금리액티브(합성)   106685        3          0
# 4   449170           6  TIGER KOFR금리액티브(합성)   105225        2         10
#
#    changeRate        nav  threeMonthEarnRate    quant  amonut  marketSum
# 0        0.01  1035156.0              0.8840   344339  356445      83168
# 1        0.01    54258.0              0.8456   132995    7216      73403
# 2        0.35    37556.0              6.5840  1895070   70864      63813
# 3        0.00   106678.0              0.8841   609048   64976      52336
# 4        0.01   105221.0              0.8869    42740    4497      37320

# %%
# 하단 데이터의 일부 미리보기
df.tail()
# Out:
#     itemcode  etfTabCode             itemname  nowVal risefall  changeVal  \
# 851   412560           2       TIGER BBIG레버리지    2210        2         25
# 852   252730           2        KBSTAR 모멘텀로우볼   16285        2         75
# 853   287330           2      KBSTAR 200생활소비재    6415        5         -5
# 854   315480           2  KBSTAR 200커뮤니케이션서비스   10965        2         25
# 855   287320           2        KBSTAR 200산업재   12495        2        125
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 851        1.14   2226.0             -0.9071   4169       9         19
# 852        0.46  16300.0              6.8204     12       0         16
# 853       -0.08   6415.0              8.2995   2140      13         14
# 854        0.23  10969.0             -1.9011    119       1         13
# 855        1.01  12504.0              8.0443    149       1         10

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러오기
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구하기
import datetime

today = datetime.datetime.today()
today = today.strftime("%Y-%m-%d")
today
# Out:
# '2024-05-08'

# %%
# f-string 방식으로 파일명
# eft_날짜_raw.csv 형태로 만들기
file_name = f"eft_{today}_raw.csv"
file_name
# Out:
# 'eft_2024-05-08_raw.csv'

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장, index 가 저장되지 않도록 하기
df.to_csv(file_name, index=False)

# %%
# 저장된 csv 파일을 읽어오기
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": np.object} 로 타입을 지정해 주면 문자형태로 읽어옴
pd.read_csv(file_name, dtype={"itemcode": np.object})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22212\2515441140.py:3: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   pd.read_csv(file_name, dtype={"itemcode": np.object})
#     itemcode  etfTabCode             itemname   nowVal  risefall  changeVal  \
# 0     459580           6    KODEX CD금리액티브(합성)  1035155         2        100
# 1     357870           6  TIGER CD금리투자KIS(합성)    54265         2          5
# 2     069500           1            KODEX 200    37460         2        130
# 3     423160           6  KODEX KOFR금리액티브(합성)   106685         3          0
# 4     449170           6  TIGER KOFR금리액티브(합성)   105225         2         10
# ..       ...         ...                  ...      ...       ...        ...
# 851   412560           2       TIGER BBIG레버리지     2210         2         25
# 852   252730           2        KBSTAR 모멘텀로우볼    16285         2         75
# 853   287330           2      KBSTAR 200생활소비재     6415         5         -5
# 854   315480           2  KBSTAR 200커뮤니케이션서비스    10965         2         25
# 855   287320           2        KBSTAR 200산업재    12495         2        125
#
#      changeRate        nav  threeMonthEarnRate    quant  amonut  marketSum
# 0          0.01  1035156.0              0.8840   344339  356445      83168
# 1          0.01    54258.0              0.8456   132995    7216      73403
# 2          0.35    37556.0              6.5840  1895070   70864      63813
# 3          0.00   106678.0              0.8841   609048   64976      52336
# 4          0.01   105221.0              0.8869    42740    4497      37320
# ..          ...        ...                 ...      ...     ...        ...
# 851        1.14     2226.0             -0.9071     4169       9         19
# 852        0.46    16300.0              6.8204       12       0         16
# 853       -0.08     6415.0              8.2995     2140      13         14
# 854        0.23    10969.0             -1.9011      119       1         13
# 855        1.01    12504.0              8.0443      149       1         10
#
# [856 rows x 12 columns]
